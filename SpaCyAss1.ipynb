# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
# Read the text files

# Read the "Moby Dick" extract
with open("mobydick.txt", "r", encoding="utf-8", errors="replace") as file:
    moby_dick_text = file.read()

# Read the ai_forecast1.txt file
with open("ai_forecast1.txt", "r", encoding="utf-8", errors="replace") as file:
    ai_forecast1_text = file.read()

# Read the ai_forecast2.txt file
with open("ai_forecast2.txt", "r", encoding="utf-8", errors="replace") as file:
    ai_forecast2_text = file.read()

# %%
# Process the text with SpaCy

# Increase the maximum length allowed by SpaCy
nlp.max_length = len(moby_dick_text)

doc_moby_dick = nlp(moby_dick_text)
doc_ai_forecast1 = nlp(ai_forecast1_text)
doc_ai_forecast2 = nlp(ai_forecast2_text)

# %%
# Print named entities in the "Moby Dick" extract
for ent in doc_moby_dick.ents:
    print(ent.text, ent.label_)
# Out:
# WHALE ORG
# Herman Melville PERSON
# CHAPTER 1 LAW
# CHAPTER 2 LAW
# Carpet-Bag ORG
# CHAPTER 3 LAW
# The Spouter-Inn ORG
# CHAPTER 4 LAW
# Counterpane ORG
# CHAPTER 5 LAW
# CHAPTER 6 LAW
# CHAPTER 7 LAW
# CHAPTER 8 LAW
# CHAPTER 9 LAW
# Sermon PERSON
# CHAPTER 10 LAW
# Bosom Friend ORG
# CHAPTER 11 LAW
# CHAPTER 12 LAW
# CHAPTER 13 LAW
# CHAPTER 14 LAW
# CHAPTER 15 LAW
# CHAPTER 16 LAW
# CHAPTER 17 LAW
# CHAPTER 18 LAW
# Mark PERSON
# CHAPTER 19 LAW
# CHAPTER 20 LAW
# CHAPTER 21 LAW
# Going Aboard PERSON
# CHAPTER 22 LAW
# Christmas DATE
# CHAPTER 23 LAW
# The Lee Shore ORG
# CHAPTER 24 LAW
# Advocate ORG
# CHAPTER 25 LAW
# CHAPTER 26 LAW
# Knights and Squires ORG
# CHAPTER 27 LAW
# Knights and Squires ORG
# CHAPTER 28 LAW
# CHAPTER 29 LAW
# Ahab PERSON
# CHAPTER 30 LAW
# Pipe FAC
# CHAPTER 31 LAW
# Queen Mab PERSON
# CHAPTER 32 LAW
# CHAPTER 33 LAW
# Specksnyder ORG
# CHAPTER 34 LAW
# The Cabin-Table ORG
# CHAPTER 35 LAW
# CHAPTER 36 LAW
# The Quarter-Deck ORG
# CHAPTER 37 LAW
# CHAPTER 38 LAW
# CHAPTER 39 LAW
# First Night-Watch ORG
# CHAPTER 40 LAW
# Midnight TIME
# Forecastle PERSON
# CHAPTER 41 LAW
# Moby Dick PERSON
# CHAPTER 42 LAW
# The Whiteness of the Whale ORG
# CHAPTER 43 LAW
# CHAPTER 44 LAW
# Chart ORG
# CHAPTER 45 LAW
# Affidavit GPE
# CHAPTER 46 LAW
# CHAPTER 47 LAW
# The Mat-Maker ORG
# CHAPTER 48 LAW
# The First Lowering ORG
# CHAPTER 49 LAW
# Hyena GPE
# CHAPTER 50 LAW
# Ahab’s Boat PERSON
# Crew PERSON
# Fedallah PERSON
# CHAPTER 51 LAW
# CHAPTER 52 LAW
# Albatross LOC
# CHAPTER 53 LAW
# CHAPTER 54 LAW
# Sperm Whale PERSON
# the Sperm Whale GPE
# late years DATE
# Thomas Beale PERSON
# 1839 DATE
# The Cachalot WORK_OF_ART
# Sperm Whale PERSON
# the True
#   Whale ORG
# Frederick Debell Bennett PERSON
# Globe ORG
# 1840 DATE
# October 13 DATE
# Three CARDINAL
# lee PERSON
# there—_thar PERSON
# Two miles and a half QUANTITY
# J. Ross Browne’s PERSON
# 1846 DATE
# The Whale-ship WORK_OF_ART
# Globe ORG
# Narrative of the Globe Mutiny WORK_OF_ART
# Lay PERSON
# Hussey PERSON
# A.D. GPE
# 1828 DATE
# Bennett PERSON
# Webster PERSON
# National ORG
# eight or nine thousand CARDINAL
# Daniel Webster PERSON
# the U. S. Senate GPE
# 1828 DATE
# The Whale WORK_OF_ART
# Captors ORG
# Whaleman PERSON
# the Homeward Cruise FAC
# Preble PERSON
# Henry T. Cheever PERSON
# Samuel PERSON
# William Comstock PERSON
# Globe ORG
# Dutch NORP
# English LANGUAGE
# the Northern Ocean LOC
# India GPE
# McCulloch’s ORG
# North-West Passage ORG
# Currents PERSON
# Whaling GPE
# U.S. GPE
# Pedestrians NORP
# London GPE
# the Arctic Ocean LOC
# Newspaper Account PERSON
# American NORP
# Cruise PERSON
# Whale Boat ORG
# Miriam Coffin PERSON
# The Whale WORK_OF_ART
# Ribs LOC
# one CARDINAL
# two CARDINAL
# Terra Del Fuego PERSON
# Darwin PERSON
# Naturalist NORP
# Sperm Whale PERSON
# Wharton PERSON
# Nantucket Song PERSON
# Whale GPE
# Whale Song PERSON
# CHAPTER 1 LAW
# Some years ago DATE
# November DATE
# Cato ORG
# Indian NORP
# a few hours TIME
# Sabbath afternoon PERSON
# Corlears
# Hook LOC
# Whitehall ORG
# thousands upon thousands CARDINAL
# China GPE
# week days DATE
# north, east GPE
# ten CARDINAL
# American NORP
# Prairies ORG
# June DATE
# one CARDINAL
# Niagara PERSON
# thousand miles QUANTITY
# Tennessee GPE
# two CARDINAL
# Rockaway Beach GPE
# first ORDINAL
# first ORDINAL
# Persians NORP
# Greeks PERSON
# Jove PERSON
# Narcissus PERSON
# don’t PRODUCT
# nights TIME
# Cook PERSON
# barques ORG
# brigs PERSON
# Egyptians NORP
# May DATE
# first ORDINAL
# Van Rensselaers ORG
# Randolphs NORP
# Hardicanutes LOC
# Seneca GPE
# Stoics ORG
# the New Testament ORG
# Gabriel PERSON
# one CARDINAL
# a single
# penny MONEY
# two CARDINAL
# Pythagorean NORP
# second ORDINAL
# first ORDINAL
# Fates NORP
# Providence GPE
# the United States GPE
# ONE CARDINAL
# AFFGHANISTAN ORG
# Fates GPE
# thousand CARDINAL
# Patagonian NORP
# one CARDINAL
# two CARDINAL
# two CARDINAL
# CHAPTER 2 LAW
# Carpet-Bag ORG
# two CARDINAL
# Cape Horn LOC
# Pacific LOC
# Manhatto PERSON
# New Bedford GPE
# Saturday DATE
# night TIME
# December DATE
# Nantucket ORG
# Monday DATE
# New Bedford GPE
# Nantucket GPE
# New Bedford GPE
# Nantucket GPE
# Nantucket GPE
# first ORDINAL
# American NORP
# Nantucket GPE
# the Red-Men ORG
# first ORDINAL
# Leviathan GPE
# Nantucket GPE
# first ORDINAL
# a night TIME
# another night TIME
# New Bedford GPE
# Ishmael GPE
# the night TIME
# Ishmael PERSON
# The
# Crossed WORK_OF_ART
# Sword-Fish Inn WORK_OF_ART
# ten inches QUANTITY
# one CARDINAL
# Ishmael GPE
# this hour of the night TIME
# the last day of the week DATE
# that quarter DATE
# Gomorrah PERSON
# The Crossed Harpoons WORK_OF_ART
# The Sword-Fish?”—this WORK_OF_ART
# “The Trap WORK_OF_ART
# second ORDINAL
# Black Parliament ORG
# Tophet GPE
# A hundred CARDINAL
# Angel PERSON
# Doom PERSON
# Ishmael GPE
# Spouter LOC
# Coffin GPE
# I. ORG
# Nantucket GPE
# Peter PERSON
# one CARDINAL
# Euroclydon GPE
# Paul PERSON
# Euroclydon GPE
# one CARDINAL
# Euroclydon PERSON
# Death PERSON
# a million years ago DATE
# Euroclydon GPE
# Euroclydon GPE
# one CARDINAL
# summer DATE
# Lazarus PERSON
# Lazarus PERSON
# Sumatra NORP
# Lazarus ORG
# one CARDINAL
# Moluccas GPE
# Czar PERSON
# CHAPTER 3 LAW
# The Spouter-Inn ORG
# Spouter-Inn ORG
# one CARDINAL
# one CARDINAL
# first ORDINAL
# England GPE
# over three CARDINAL
# half CARDINAL
# the Black Sea LOC
# four CARDINAL
# Hyperborean ORG
# Time ORG
# one CARDINAL
# half CARDINAL
# three CARDINAL
# three CARDINAL
# fifty years ago DATE
# Nathan
# Swain PERSON
# fifteen CARDINAL
# Javan GPE
# years DATE
# the Cape of Blanco LOC
# forty feet QUANTITY
# one CARDINAL
# Jonah PERSON
# penny MONEY
# Cape Horn LOC
# two CARDINAL
# half CARDINAL
# Battery LOC
# one CARDINAL
# Iceland GPE
# two CARDINAL
# One CARDINAL
# Landlord PERSON
# the
# harpooneer WORK_OF_ART
# don’t GPE
# I. “ PERSON
# That’s the Grampus’s WORK_OF_ART
# this morning TIME
# three years DATE
# Feegees ORG
# Labrador GPE
# first ORDINAL
# Jonah PERSON
# One CARDINAL
# Jonah PERSON
# Labrador GPE
# one CARDINAL
# six
# feet QUANTITY
# Southerner PRODUCT
# the Alleghanian Ridge GPE
# Virginia GPE
# a few minutes TIME
# Bulkington PERSON
# Bulkington PERSON
# Bulkington PERSON
# about nine o’clock TIME
# two CARDINAL
# two CARDINAL
# two CARDINAL
# one CARDINAL
# midnight TIME
# Landlord PERSON
# first ORDINAL
# about four inches QUANTITY
# first ORDINAL
# second ORDINAL
# the next
# morning TIME
# Landlord WORK_OF_ART
# late hours TIME
# airley PERSON
# Can’t WORK_OF_ART
# Saturday DATE
# night TIME
# Sunday DATE
# morning TIME
# I. ORG
# brown PERSON
# Broke WORK_OF_ART
# Sartain GPE
# Landlord PERSON
# Mt. Hecla LOC
# one CARDINAL
# half CARDINAL
# half CARDINAL
# first ORDINAL
# New Zealand GPE
# Sunday DATE
# last Sunday DATE
# four CARDINAL
# Saturday DATE
# night TIME
# Sabbath PERSON
# Sal PERSON
# two CARDINAL
# Sal PERSON
# Sam PERSON
# Johnny PERSON
# about one night TIME
# Sam PERSON
# Sal PERSON
# Sunday DATE
# four CARDINAL
# four CARDINAL
# one CARDINAL
# harpooneer FAC
# Indian NORP
# South American NORP
# Christian NORP
# a rainy day DATE
# half CARDINAL
# all that night TIME
# Nod PERSON
# New
# Zealand GPE
# one CARDINAL
# New Zealand GPE
# second ORDINAL
# night TIME
# Thirty Years DATE
# War EVENT
# whaleman PERSON
# the South Seas LOC
# Christian NORP
# three days DATE
# Congo GPE
# Congo GPE
# half CARDINAL
# First ORDINAL
# you?”—he PRODUCT
# Landlord PERSON
# Peter Coffin PERSON
# I. ORG
# Coffin GPE
# Speak-e! WORK_OF_ART
# Queequeg NORP
# Queequeg GPE
# one CARDINAL
# Christian NORP
# Landlord PERSON
# Queequeg GPE
# CHAPTER 4 LAW
# Counterpane ORG
# next morning TIME
# Queequeg PERSON
# Cretan GPE
# two CARDINAL
# one CARDINAL
# first ORDINAL
# Queequeg GPE
# a few days DATE
# supperless,—my ORG
# the 21st June DATE
# the longest day DATE
# the year DATE
# third ORDINAL
# sixteen entire hours TIME
# Sixteen hours TIME
# several hours TIME
# half CARDINAL
# one single inch QUANTITY
# the morning TIME
# days DATE
# weeks DATE
# months DATE
# this very hour TIME
# Queequeg GPE
# the past night TIME
# one CARDINAL
# Queequeg GPE
# Newfoundland GPE
# first ORDINAL
# Queequeg NORP
# Queequeg GPE
# Queequeg NORP
# Queequeg NORP
# caterpillar ORG
# first ORDINAL
# Queequeg NORP
# Christian NORP
# Queequeg GPE
# Queequeg NORP
# CHAPTER 5 LAW
# one CARDINAL
# second ORDINAL
# third ORDINAL
# morning TIME
# three days DATE
# Indian NORP
# satin NORP
# third ORDINAL
# weeks DATE
# Queequeg GPE
# Andes LOC
# New England LOC
# Mungo Park FAC
# Scotch NORP
# Siberia LOC
# Africa LOC
# Mungo WORK_OF_ART
# the Green
# Mountains LOC
# Queequeg NORP
# Queequeg NORP
# Queequeg GPE
# first ORDINAL
# Queequeg NORP
# first ORDINAL
# New Bedford GPE
# Broadway FAC
# Chestnut PERSON
# Mediterranean LOC
# Lascars GPE
# Malays DATE
# Bombay GPE
# the Apollo Green ORG
# Yankees ORG
# New Bedford GPE
# Wapping GPE
# New Bedford GPE
# Feegeeans NORP
# Tongatobooarrs ORG
# Erromanggoans NORP
# Pannangians NORP
# Brighggians NORP
# weekly DATE
# New Hampshire GPE
# the Green Mountains LOC
# a few hours old TIME
# two acres QUANTITY
# first ORDINAL
# New Bedford GPE
# this day DATE
# Labrador GPE
# New England LOC
# Canaan PERSON
# America GPE
# New
# Bedford GPE
# Atlantic LOC
# Pacific LOC
# Indian NORP
# One CARDINAL
# Herr Alexander PERSON
# New Bedford GPE
# New Bedford GPE
# summer DATE
# August DATE
# New Bedford GPE
# New Bedford GPE
# summer DATE
# seventh ORDINAL
# Salem GPE
# Moluccas GPE
# Puritanic PERSON
# New Bedford GPE
# Whaleman PERSON
# second ORDINAL
# third ORDINAL
# Moss PERSON
# Tartar PERSON
# Queequeg NORP
# Moss PERSON
# Sultan LOC
# two CARDINAL
# Indian NORP
# two CARDINAL
# one CARDINAL
# Queequeg GPE
# Capting, Capting WORK_OF_ART
# Hallo WORK_OF_ART
# Queequeg GPE
# Queequeg GPE
# Queequeg NORP
# Queequeg NORP
# Queequeg NORP
# Queequeg NORP
# Queequeg NORP
# Queequeg GPE
# three minutes TIME
# Queequeg LANGUAGE
# A few minutes TIME
# Queequeg NORP
# that hour TIME
# Queequeg GPE
# Queequeg NORP
# himself—“It ORG
# Christians NORP
# CHAPTER 14 LAW
# Nantucket GPE
# twenty years DATE
# Canada GPE
# Nantucket GPE
# Rome GPE
# summer DATE
# three CARDINAL
# day DATE
# Laplander NORP
# Nantucket GPE
# Illinois GPE
# New England LOC
# Indian NORP
# Indian NORP
# Nantucketers PERSON
# first ORDINAL
# Behring’s Straits WORK_OF_ART
# all seasons DATE
# Himmalehan GPE
# Mastodon GPE
# Nantucketers PERSON
# ant-hill GPE
# Alexanders ORG
# Atlantic LOC
# Pacific LOC
# Indian NORP
# three CARDINAL
# Poland GPE
# America GPE
# Mexico GPE
# Texas GPE
# Cuba GPE
# Canada GPE
# English LANGUAGE
# India GPE
# two thirds CARDINAL
# Nantucketer ORG
# Nantucketer ORG
# Bible WORK_OF_ART
# Noah PERSON
# millions CARDINAL
# China GPE
# Alps LOC
# years DATE
# Earthsman PRODUCT
# Nantucketer ORG
# CHAPTER 15 LAW
# late in the evening TIME
# Queequeg NORP
# that day DATE
# the Spouter-Inn ORG
# Hosea Hussey PERSON
# Try Pots PRODUCT
# one CARDINAL
# Nantucket GPE
# Cousin GPE
# the Try Pots FAC
# three CARDINAL
# first ORDINAL
# first ORDINAL
# Queequeg NORP
# first ORDINAL
# Peter Coffin LOC
# Two CARDINAL
# two CARDINAL
# two CARDINAL
# Queequeg GPE
# first ORDINAL
# Tophet GPE
# Queequeg NORP
# Hussey PERSON
# Hosea Hussey PERSON
# Hussey PERSON
# Hussey PERSON
# said—“Clam ORG
# Cod PERSON
# Hussey PERSON
# winter DATE
# Hussey PERSON
# Shirt PERSON
# Hussey PERSON
# two CARDINAL
# Queequeg GPE
# Queequeg NORP
# Hussey PERSON
# Queequeg GPE
# the Try Pots ORG
# Hussey PERSON
# codfish ORG
# Hosea Hussey PERSON
# one morning TIME
# Hosea PERSON
# Hussey PERSON
# Queequeg NORP
# four years and a half DATE
# only three barrels QUANTITY
# ile PERSON
# first ORDINAL
# night TIME
# Queequeg PERSON
# CHAPTER 16 LAW
# Queequeg LANGUAGE
# Yojo PERSON
# Yojo PERSON
# two or three CARDINAL
# Yojo PERSON
# Yojo PERSON
# Ishmael GPE
# Queequeg GPE
# Queequeg NORP
# Yojo PERSON
# Yojo PERSON
# Queequeg GPE
# Yojo PERSON
# Queequeg GPE
# Next morning TIME
# Queequeg NORP
# Yojo PERSON
# Lent or Ramadan WORK_OF_ART
# Queequeg NORP
# Yojo PERSON
# that day DATE
# Advocate ORG
# Queequeg NORP
# first ORDINAL
# one CARDINAL
# Martial Commanders ORG
# Dutch NORP
# De Witt’s GPE
# Louis XVI PERSON
# France GPE
# Dunkirk ORG
# two CARDINAL
# Nantucket GPE
# Britain GPE
# the years 1750 DATE
# 1788 DATE
# 1,000,000 MONEY
# America GPE
# seven hundred CARDINAL
# eighteen CARDINAL
# 4,000,000 of dollars MONEY
# 20,000,000 MONEY
# 7,000,000 MONEY
# half CARDINAL
# one CARDINAL
# sixty
# years DATE
# one CARDINAL
# One CARDINAL
# Egyptian NORP
# many years DATE
# earth LOC
# Cook PERSON
# Vancouver GPE
# American NORP
# European NORP
# first ORDINAL
# Exploring Expeditions ORG
# Krusensterns NORP
# Nantucket GPE
# Cook PERSON
# Krusenstern NORP
# Cook PERSON
# South Sea Voyages LOC
# Nantucketers PERSON
# Vancouver GPE
# three CARDINAL
# Cape Horn LOC
# Europe LOC
# Spanish NORP
# Pacific LOC
# Spanish NORP
# Peru GPE
# Chili PERSON
# Bolivia GPE
# Spain GPE
# America GPE
# Australia GPE
# first ORDINAL
# Dutchman GPE
# first ORDINAL
# Australian NORP
# Polynesia GPE
# first ORDINAL
# Japan GPE
# fifty CARDINAL
# first ORDINAL
# Leviathan GPE
# first ORDINAL
# Alfred the Great WORK_OF_ART
# Norwegian NORP
# Parliament ORG
# Edmund Burke PERSON
# Benjamin Franklin PERSON
# Mary Morrel PERSON
# Mary Folger PERSON
# one CARDINAL
# Nantucket GPE
# Folgers ORG
# kin ORG
# Benjamin PERSON
# this day DATE
# Whaling PERSON
# English LANGUAGE
# one CARDINAL
# Roman NORP
# Syrian NORP
# Cetus ORG
# South LOC
# Czar PERSON
# Queequeg GPE
# three hundred and fifty CARDINAL
# MSS ORG
# Yale College ORG
# Harvard ORG
# CHAPTER 25 LAW
# Britons GPE
# CHAPTER 26 LAW
# Knights and Squires ORG
# Pequod GPE
# Starbuck PERSON
# Nantucket GPE
# Quaker ORG
# Indies ORG
# Only some thirty CARDINAL
# Egyptian NORP
# Starbuck PERSON
# those thousand-fold CARDINAL
# Outward PERSON
# Starbuck PERSON
# second ORDINAL
# Starbuck PERSON
# Starbuck PERSON
# Starbuck PERSON
# hundreds CARDINAL
# Starbuck PERSON
# Starbuck PERSON
# Starbuck PERSON
# august DATE
# Thou shalt
#  PERSON
# one CARDINAL
# Bunyan GPE
# Thou PERSON
# Cervantes GPE
# Thou PERSON
# Andrew Jackson PERSON
# Thou PERSON
# Thy PERSON
# CHAPTER 27 LAW
# Knights and Squires ORG
# second ORDINAL
# Cape Cod PERSON
# a Cape-Cod-man PRODUCT
# journeyman joiner PERSON
# the year DATE
# flank ORG
# one CARDINAL
# first ORDINAL
# one CARDINAL
# third ORDINAL
# Flask ORG
# Tisbury ORG
# Martha GPE
# three years DATE
# Cape Horn LOC
# King-Post ORG
# Pequod GPE
# Arctic LOC
# three mates QUANTITY
# Starbuck PERSON
# Stubb PERSON
# Flask GPE
# three CARDINAL
# Pequod GPE
# Ahab PERSON
# three CARDINAL
# Africa LOC
# Babel PRODUCT
# Egyptians NORP
# Egyptians NORP
# first ORDINAL
# four CARDINAL
# Saint Stylites GPE
# Christian NORP
# Napoleon ORG
# Vendome PERSON
# some one hundred CARDINAL
# fifty feet QUANTITY
# Louis Philippe PERSON
# Louis Blanc PERSON
# Louis the Devil ORG
# Washington GPE
# Baltimore GPE
# Hercules GPE
# Nelson PERSON
# Trafalgar Square PERSON
# London GPE
# Washington GPE
# Napoleon ORG
# Nelson PERSON
# Obed Macy PERSON
# Nantucket GPE
# Obed PERSON
# A few years ago DATE
# New
# Zealand GPE
# one CARDINAL
# three CARDINAL
# every two hours TIME
# a hundred feet QUANTITY
# Colossus PERSON
# Rhodes PERSON
# three years DATE
# one CARDINAL
# a long three or four years DATE
# the various hours TIME
# several entire months DATE
# two CARDINAL
# Alps GPE
# winter DATE
# Greenland GPE
# Sleet PERSON
# A Voyage WORK_OF_ART
# Icebergs LOC
# the Greenland Whale LOC
# the Lost Icelandic Colonies of Old Greenland ORG
# Glacier LOC
# Sleet PERSON
# Sleet PERSON
# Sleet LOC
# Sleet PERSON
# Glacier LOC
# Sleet PERSON
# one CARDINAL
# three or four CARDINAL
# Southern NORP
# Sleet PERSON
# South LOC
# one CARDINAL
# Queequeg GPE
# one CARDINAL
# Nantucket GPE
# Phædon ORG
# Bowditch GPE
# Platonist NORP
# ten CARDINAL
# one CARDINAL
# Childe Harold PERSON
# Ten thousand CARDINAL
# half CARDINAL
# Platonists NORP
# one CARDINAL
# three years DATE
# thou CARDINAL
# half CARDINAL
# Cranmer ORG
# Pantheistic ORG
# Descartian NORP
# mid-day DATE
# one half CARDINAL
# summer DATE
# Pantheists NORP
# CHAPTER 36 LAW
# The Quarter-Deck ORG
# Ahab PERSON
# one morning TIME
# Ahab PERSON
# that
# hour TIME
# one CARDINAL
# that morning TIME
# Ahab PERSON
# Flask ORG
# Twill ORG
# The hours TIME
# Starbuck PERSON
# Ahab PERSON
# Ahab PERSON
# half CARDINAL
# Flask GPE
# Ahab PERSON
# Ahab PERSON
# Ahab PERSON
# half CARDINAL
# Spanish NORP
# sun—“it GPE
# sixteen dollar MONEY
# Starbuck PERSON
# Ahab PERSON
# Starbuck PERSON
# three CARDINAL
# Ahab PERSON
# Skin PERSON
# Tashtego ORG
# Daggoo GPE
# Queequeg NORP
# Captain Ahab WORK_OF_ART
# Tashtego PERSON
# Moby Dick PERSON
# Moby Dick PERSON
# Ahab PERSON
# Tash PERSON
# Gay-Header ORG
# Ahab PERSON
# two CARDINAL
# three CARDINAL
# Queequeg NORP
# Ahab PERSON
# Queequeg GPE
# Nantucket GPE
# annual DATE
# Tashtego ORG
# Moby Dick PERSON
# Dick—Moby Dick PERSON
# Captain Ahab WORK_OF_ART
# Starbuck PERSON
# Stubb and Flask ORG
# Moby Dick PERSON
# Moby Dick PERSON
# Ahab PERSON
# Aye WORK_OF_ART
# Starbuck PERSON
# Moby Dick PERSON
# Moby Dick PERSON
# Good Hope PERSON
# Horn LOC
# Norway Maelstrom GPE
# Moby Dick PERSON
# half CARDINAL
# Starbuck PERSON
# Moby Dick PERSON
# Ahab PERSON
# Nantucket GPE
# Starbuck PERSON
# thou requirest ORG
# Starbuck PERSON
# Ahab PERSON
# Starbuck PERSON
# the White
# Whale ORG
# events,—as PERSON
# a thousand miles QUANTITY
# whaleman PERSON
# the White Whale ORG
# half CARDINAL
# Moby Dick PERSON
# the White
# Whale FAC
# the present day DATE
# the Sperm
# Whale GPE
# this day DATE
# the Sperm Whale ORG
# American NORP
# the Sperm Whale LOC
# North LOC
# Southern NORP
# Sperm Whale WORK_OF_ART
# the Sperm Whale LOC
# Cuvier’s ORG
# Baron PERSON
# the Sperm Whale GPE
# Povelson PERSON
# Moby Dick PERSON
# the earlier days DATE
# the Sperm Whale LOC
# Moby Dick PERSON
# One CARDINAL
# the White Whale ORG
# Moby Dick PERSON
# the Sperm
# Whale GPE
# American NORP
# English LANGUAGE
# years ago DATE
# Scoresby PERSON
# Pacific LOC
# Greenland GPE
# two CARDINAL
# Strello PERSON
# Portugal GPE
# Arethusa PERSON
# Syracuse GPE
# the Holy
# Land ORG
# the White Whale ORG
# Moby Dick PERSON
# hundreds CARDINAL
# the White Whale ORG
# the White Whale’s ORG
# three CARDINAL
# one CARDINAL
# Arkansas GPE
# six inch QUANTITY
# Ahab PERSON
# Moby Dick PERSON
# Ahab PERSON
# Venetian NORP
# Malay LANGUAGE
# Ahab PERSON
# half CARDINAL
# half CARDINAL
# Christians NORP
# one-half CARDINAL
# Ophites GPE
# Ahab PERSON
# Moby PERSON
# Dick PERSON
# Adam PERSON
# months of days DATE
# weeks DATE
# Ahab PERSON
# one CARDINAL
# mid winter DATE
# ...
# some few weeks DATE
# Ahab’s PERSON
# Nantucket GPE
# Bachelor ORG
# three CARDINAL
# three CARDINAL
# two barrels QUANTITY
# Bachelor ORG
# entire months DATE
# Pequod GPE
# Polynesian NORP
# three CARDINAL
# Bastille GPE
# Ahab PERSON
# two CARDINAL
# two CARDINAL
# Bachelor ORG
# Ahab PERSON
# two CARDINAL
# Ahab PERSON
# Thou PERSON
# one CARDINAL
# two CARDINAL
# Pequod GPE
# Bachelor ORG
# Bachelor ORG
# Ahab PERSON
# two CARDINAL
# Nantucket ORG
# CHAPTER 116 LAW
# Pequod GPE
# next day DATE
# Bachelor ORG
# four CARDINAL
# one CARDINAL
# Ahab PERSON
# the afternoon TIME
# Manilla PERSON
# Spanish NORP
# Ahab PERSON
# Ahab
#  PERSON
# Chinese NORP
# Niger ORG
# Hindoo PERSON
# Typhoon DATE
# one CARDINAL
# one CARDINAL
# half CARDINAL
# CHAPTER 117 LAW
# four CARDINAL
# evening TIME
# leeward ORG
# one CARDINAL
# one CARDINAL
# three CARDINAL
# morning TIME
# all night TIME
# Ahab PERSON
# Ahab PERSON
# Parsee GPE
# Asphaltites NORP
# Gomorrah ORG
# Ahab PERSON
# Parsee GPE
# two CARDINAL
# first ORDINAL
# America GPE
# two CARDINAL
# Moby Dick PERSON
# Parsee GPE
# Ahab PERSON
# one CARDINAL
# Quadrant PERSON
# every day DATE
# Ahab PERSON
# Ahab PERSON
# daily DATE
# Japanese NORP
# the days DATE
# summer DATE
# Japanese NORP
# Ahab PERSON
# Parsee GPE
# Ahab’s PERSON
# Moby Dick PERSON
# Ahab PERSON
# Starbuck PERSON
# the third
# day DATE
# Moby Dick PERSON
# thou GPE
# thou GPE
# Ahab PERSON
# Starbuck PERSON
# Tashtego PERSON
# Queequeg GPE
# Daggoo GPE
# three CARDINAL
# two CARDINAL
# One CARDINAL
# Stubb and Flask ORG
# Tashtego ORG
# the three days DATE
# the White
# Whale FAC
# Ahab PERSON
# tell”—he GPE
# two CARDINAL
# the White Whale’s ORG
# Ahab PERSON
# Monadnock PERSON
# Moby Dick PERSON
# Ahab PERSON
# three CARDINAL
# two CARDINAL
# third ORDINAL
# the White Whale ORG
# Ahab PERSON
# Ahab PERSON
# Ahab PERSON
# two CARDINAL
# half CARDINAL
# Tashtego ORG
# half CARDINAL
# Starbuck PERSON
# Stubb PERSON
# Starbuck PERSON
# Ahab, Ahab PERSON
# moon PERSON
# Flask GPE
# one CARDINAL
# second ORDINAL
# Ahab PERSON
# American NORP
# a few yards QUANTITY
# Ahab PERSON
# Tashtego ORG
# three CARDINAL
# haughty helm PERSON
# ho GPE
# one CARDINAL
# grooves;—ran GPE
# Ahab PERSON
# Turkish NORP
# Fata GPE
# Morgana ORG
# fidelity ORG
# one CARDINAL
# Pequod GPE
# Indian NORP
# a few inches QUANTITY
# almost touched;—at CARDINAL
# Tashtego ORG
# Ahab PERSON
# Satan DATE
# five thousand years ago DATE
# one CARDINAL
# one CARDINAL
# Parsee GPE
# Fates GPE
# Ahab PERSON
# the last day DATE
# three CARDINAL
# one CARDINAL
# the second day DATE
# Rachel PERSON

# %%
# Perform tokenization, POS tagging, sentence parsing (dep) and named entity recognition (NER) on ai_forecast1
print("Analysis of ai_forecast1.txt")
for sent in doc_ai_forecast1.sents:
    print(f"\nSentence: {sent.text}\n")

    for token in sent: 
        print(f"Token: {token.text}, POS: {token.pos_}, Dep: {token.dep_}, Head: {token.head.text}")

# Named entities in ai_forecast1
print("\nNamed Entities in ai_forecast1:")
for ent in doc_ai_forecast1.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Analysis of ai_forecast1.txt
#
# Sentence: Pune, India, Sept. 13, 2022 (GLOBE NEWSWIRE) --
#
# Token: Pune, POS: PROPN, Dep: ROOT, Head: Pune
# Token: ,, POS: PUNCT, Dep: punct, Head: Pune
# Token: India, POS: PROPN, Dep: appos, Head: Pune
# Token: ,, POS: PUNCT, Dep: punct, Head: Pune
# Token: Sept., POS: PROPN, Dep: npadvmod, Head: Pune
# Token: 13, POS: NUM, Dep: nummod, Head: Sept.
# Token: ,, POS: PUNCT, Dep: punct, Head: Sept.
# Token: 2022, POS: NUM, Dep: nummod, Head: Sept.
# Token: (, POS: PUNCT, Dep: punct, Head: Pune
# Token: GLOBE, POS: PROPN, Dep: compound, Head: NEWSWIRE
# Token: NEWSWIRE, POS: PROPN, Dep: appos, Head: Pune
# Token: ), POS: PUNCT, Dep: punct, Head: Pune
# Token: --, POS: PUNCT, Dep: punct, Head: Pune
#
# Sentence: The global AI market size is projected to grow from USD 387.45 billion in 2022 to USD 1394.30 billion in 2029 at a CAGR of 20.1% in the forecast period.
#
# Token: The, POS: DET, Dep: det, Head: size
# Token: global, POS: ADJ, Dep: amod, Head: size
# Token: AI, POS: PROPN, Dep: compound, Head: size
# Token: market, POS: NOUN, Dep: compound, Head: size
# Token: size, POS: NOUN, Dep: nsubjpass, Head: projected
# Token: is, POS: AUX, Dep: auxpass, Head: projected
# Token: projected, POS: VERB, Dep: ROOT, Head: projected
# Token: to, POS: PART, Dep: aux, Head: grow
# Token: grow, POS: VERB, Dep: xcomp, Head: projected
# Token: from, POS: ADP, Dep: prep, Head: grow
# Token: USD, POS: NOUN, Dep: quantmod, Head: billion
# Token: 387.45, POS: NUM, Dep: compound, Head: billion
# Token: billion, POS: NUM, Dep: pobj, Head: from
# Token: in, POS: ADP, Dep: prep, Head: billion
# Token: 2022, POS: NUM, Dep: pobj, Head: in
# Token: to, POS: ADP, Dep: prep, Head: grow
# Token: USD, POS: NOUN, Dep: quantmod, Head: billion
# Token: 1394.30, POS: NUM, Dep: compound, Head: billion
# Token: billion, POS: NUM, Dep: pobj, Head: to
# Token: in, POS: ADP, Dep: prep, Head: billion
# Token: 2029, POS: NUM, Dep: pobj, Head: in
# Token: at, POS: ADP, Dep: prep, Head: grow
# Token: a, POS: DET, Dep: det, Head: CAGR
# Token: CAGR, POS: PROPN, Dep: pobj, Head: at
# Token: of, POS: ADP, Dep: prep, Head: CAGR
# Token: 20.1, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: pobj, Head: of
# Token: in, POS: ADP, Dep: prep, Head: CAGR
# Token: the, POS: DET, Dep: det, Head: period
# Token: forecast, POS: NOUN, Dep: compound, Head: period
# Token: period, POS: NOUN, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: projected
#
# Sentence: Growing investment in AI technology by enterprises of all sizes across industries to garner momentum in the next several years.
#
# Token: Growing, POS: VERB, Dep: amod, Head: investment
# Token: investment, POS: NOUN, Dep: ROOT, Head: investment
# Token: in, POS: ADP, Dep: prep, Head: investment
# Token: AI, POS: PROPN, Dep: compound, Head: technology
# Token: technology, POS: NOUN, Dep: pobj, Head: in
# Token: by, POS: ADP, Dep: prep, Head: investment
# Token: enterprises, POS: NOUN, Dep: pobj, Head: by
# Token: of, POS: ADP, Dep: prep, Head: enterprises
# Token: all, POS: DET, Dep: det, Head: sizes
# Token: sizes, POS: NOUN, Dep: pobj, Head: of
# Token: across, POS: ADP, Dep: prep, Head: sizes
# Token: industries, POS: NOUN, Dep: pobj, Head: across
# Token: to, POS: PART, Dep: aux, Head: garner
# Token: garner, POS: VERB, Dep: acl, Head: investment
# Token: momentum, POS: NOUN, Dep: dobj, Head: garner
# Token: in, POS: ADP, Dep: prep, Head: garner
# Token: the, POS: DET, Dep: det, Head: years
# Token: next, POS: ADJ, Dep: amod, Head: years
# Token: several, POS: ADJ, Dep: amod, Head: years
# Token: years, POS: NOUN, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: investment
#
# Sentence: Fortune Business Insights� published this information in its recent report, titled �Artificial Intelligence Market Forecast, 2022-2029.
#
# Token: Fortune, POS: PROPN, Dep: compound, Head: Insights
# Token: Business, POS: PROPN, Dep: compound, Head: Insights
# Token: Insights, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: NOUN, Dep: nsubj, Head: published
# Token: published, POS: VERB, Dep: ROOT, Head: published
# Token: this, POS: DET, Dep: det, Head: information
# Token: information, POS: NOUN, Dep: dobj, Head: published
# Token: in, POS: ADP, Dep: prep, Head: published
# Token: its, POS: PRON, Dep: poss, Head: report
# Token: recent, POS: ADJ, Dep: amod, Head: report
# Token: report, POS: NOUN, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: report
# Token: titled, POS: VERB, Dep: acl, Head: report
# Token: �, POS: NOUN, Dep: compound, Head: Forecast
# Token: Artificial, POS: PROPN, Dep: compound, Head: Forecast
# Token: Intelligence, POS: PROPN, Dep: compound, Head: Forecast
# Token: Market, POS: PROPN, Dep: compound, Head: Forecast
# Token: Forecast, POS: PROPN, Dep: dobj, Head: titled
# Token: ,, POS: PUNCT, Dep: punct, Head: Forecast
# Token: 2022, POS: NUM, Dep: npadvmod, Head: Forecast
# Token: -, POS: SYM, Dep: punct, Head: 2029
# Token: 2029, POS: NUM, Dep: prep, Head: 2022
# Token: ., POS: PUNCT, Dep: punct, Head: published
#
# Sentence: � As per the report, the global market size was USD 328.34 billion in 2021.
#
#
# Token: �, POS: NOUN, Dep: compound, Head: As
# Token: As, POS: ADP, Dep: prep, Head: was
# Token: per, POS: ADP, Dep: prep, Head: As
# Token: the, POS: DET, Dep: det, Head: report
# Token: report, POS: NOUN, Dep: pobj, Head: per
# Token: ,, POS: PUNCT, Dep: punct, Head: was
# Token: the, POS: DET, Dep: det, Head: size
# Token: global, POS: ADJ, Dep: amod, Head: size
# Token: market, POS: NOUN, Dep: compound, Head: size
# Token: size, POS: NOUN, Dep: nsubj, Head: was
# Token: was, POS: AUX, Dep: ROOT, Head: was
# Token: USD, POS: NOUN, Dep: quantmod, Head: billion
# Token: 328.34, POS: NUM, Dep: compound, Head: billion
# Token: billion, POS: NUM, Dep: attr, Head: was
# Token: in, POS: ADP, Dep: prep, Head: was
# Token: 2021, POS: NUM, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: was
# Token:
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: The rising demand for artificial intelligence technology across various induce verticals such as a retail, BFSI, healthcare, food and beverages, automotive, and logistics is significantly contributing towards the growth of the global market.
#
#
#
# Token: The, POS: DET, Dep: det, Head: demand
# Token: rising, POS: VERB, Dep: amod, Head: demand
# Token: demand, POS: NOUN, Dep: nsubj, Head: contributing
# Token: for, POS: ADP, Dep: prep, Head: demand
# Token: artificial, POS: ADJ, Dep: amod, Head: technology
# Token: intelligence, POS: NOUN, Dep: compound, Head: technology
# Token: technology, POS: NOUN, Dep: pobj, Head: for
# Token: across, POS: ADP, Dep: prep, Head: demand
# Token: various, POS: ADJ, Dep: amod, Head: verticals
# Token: induce, POS: NOUN, Dep: compound, Head: verticals
# Token: verticals, POS: NOUN, Dep: pobj, Head: across
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: verticals
# Token: a, POS: DET, Dep: det, Head: BFSI
# Token: retail, POS: NOUN, Dep: nmod, Head: BFSI
# Token: ,, POS: PUNCT, Dep: punct, Head: BFSI
# Token: BFSI, POS: PROPN, Dep: pobj, Head: as
# Token: ,, POS: PUNCT, Dep: punct, Head: BFSI
# Token: healthcare, POS: NOUN, Dep: conj, Head: BFSI
# Token: ,, POS: PUNCT, Dep: punct, Head: healthcare
# Token: food, POS: NOUN, Dep: conj, Head: healthcare
# Token: and, POS: CCONJ, Dep: cc, Head: food
# Token: beverages, POS: NOUN, Dep: conj, Head: food
# Token: ,, POS: PUNCT, Dep: punct, Head: healthcare
# Token: automotive, POS: ADJ, Dep: conj, Head: healthcare
# Token: ,, POS: PUNCT, Dep: punct, Head: automotive
# Token: and, POS: CCONJ, Dep: cc, Head: automotive
# Token: logistics, POS: NOUN, Dep: conj, Head: automotive
# Token: is, POS: AUX, Dep: aux, Head: contributing
# Token: significantly, POS: ADV, Dep: advmod, Head: contributing
# Token: contributing, POS: VERB, Dep: ROOT, Head: contributing
# Token: towards, POS: ADP, Dep: prep, Head: contributing
# Token: the, POS: DET, Dep: det, Head: growth
# Token: growth, POS: NOUN, Dep: pobj, Head: towards
# Token: of, POS: ADP, Dep: prep, Head: growth
# Token: the, POS: DET, Dep: det, Head: market
# Token: global, POS: ADJ, Dep: amod, Head: market
# Token: market, POS: NOUN, Dep: pobj, Head: of
# Token: ., POS: PUNCT, Dep: punct, Head: contributing
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Request a Sample Copy of the Research Report:
#
#
# Token: Request, POS: VERB, Dep: ROOT, Head: Request
# Token: a, POS: DET, Dep: det, Head: Copy
# Token: Sample, POS: PROPN, Dep: compound, Head: Copy
# Token: Copy, POS: PROPN, Dep: dobj, Head: Request
# Token: of, POS: ADP, Dep: prep, Head: Copy
# Token: the, POS: DET, Dep: det, Head: Report
# Token: Research, POS: PROPN, Dep: compound, Head: Report
# Token: Report, POS: PROPN, Dep: pobj, Head: of
# Token: :, POS: PUNCT, Dep: punct, Head: Copy
# Token:
# , POS: SPACE, Dep: dep, Head: :
#
# Sentence: https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
#
#
# Token: https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114, POS: NOUN, Dep: compound, Head: Microsoft
# Token:
#
# , POS: SPACE, Dep: dep, Head: https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
# Token: Microsoft, POS: PROPN, Dep: nsubj, Head: accelerates
# Token: accelerates, POS: VERB, Dep: ROOT, Head: accelerates
# Token: industry, POS: NOUN, Dep: compound, Head: strategy
# Token: cloud, POS: NOUN, Dep: compound, Head: strategy
# Token: strategy, POS: NOUN, Dep: dobj, Head: accelerates
# Token: for, POS: ADP, Dep: prep, Head: strategy
# Token: healthcare, POS: NOUN, Dep: pobj, Head: for
# Token: with, POS: ADP, Dep: prep, Head: healthcare
# Token: the, POS: DET, Dep: det, Head: acquisition
# Token: acquisition, POS: NOUN, Dep: pobj, Head: with
# Token: of, POS: ADP, Dep: prep, Head: acquisition
# Token: Nuance, POS: PROPN, Dep: pobj, Head: of
# Token:
#
# , POS: SPACE, Dep: dep, Head: Nuance
# Token: April, POS: PROPN, Dep: pobj, Head: of
# Token: 12, POS: NUM, Dep: nummod, Head: April
# Token: ,, POS: PUNCT, Dep: punct, Head: April
# Token: 2021, POS: NUM, Dep: nummod, Head: April
# Token: |, POS: NOUN, Dep: compound, Head: Share
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Center
# Token: News, POS: PROPN, Dep: compound, Head: Center
# Token: Center, POS: PROPN, Dep: compound, Head: Share
# Token:
#
# , POS: SPACE, Dep: dep, Head: Center
# Token: Share, POS: PROPN, Dep: npadvmod, Head: accelerates
# Token: on, POS: ADP, Dep: prep, Head: Share
# Token: Facebook, POS: PROPN, Dep: pobj, Head: on
# Token: (, POS: PUNCT, Dep: punct, Head: opens
# Token: opens, POS: VERB, Dep: parataxis, Head: accelerates
# Token: new, POS: ADJ, Dep: amod, Head: window
# Token: window, POS: NOUN, Dep: dobj, Head: opens
# Token: ), POS: PUNCT, Dep: punct, Head: opens
# Token:
# , POS: SPACE, Dep: dep, Head: )
#
# Sentence: Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
#
#
# Token: Share, POS: NOUN, Dep: nsubj, Head: opens
# Token: on, POS: ADP, Dep: prep, Head: Share
# Token: LinkedIn, POS: PROPN, Dep: pobj, Head: on
# Token: (, POS: PUNCT, Dep: punct, Head: opens
# Token: opens, POS: VERB, Dep: ROOT, Head: opens
# Token: new, POS: ADJ, Dep: amod, Head: window
# Token: window, POS: NOUN, Dep: dobj, Head: opens
# Token: ), POS: PUNCT, Dep: punct, Head: opens
# Token:
#
#     , POS: SPACE, Dep: dep, Head: )
# Token: Share, POS: PROPN, Dep: dobj, Head: opens
# Token: on, POS: ADP, Dep: prep, Head: Share
# Token: Twitter, POS: PROPN, Dep: pobj, Head: on
# Token: (, POS: PUNCT, Dep: punct, Head: opens
# Token: opens, POS: VERB, Dep: conj, Head: opens
# Token: new, POS: ADJ, Dep: amod, Head: window
# Token: window, POS: NOUN, Dep: dobj, Head: opens
# Token: ), POS: PUNCT, Dep: punct, Head: opens
# Token:
#
# , POS: SPACE, Dep: dep, Head: )
#
# Sentence: Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass. � April 12, 2021 � Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuance�s net debt.
#
# Token: Acquisition, POS: PROPN, Dep: nsubj, Head: combine
# Token: will, POS: AUX, Dep: aux, Head: combine
# Token: combine, POS: VERB, Dep: ROOT, Head: combine
# Token: solutions, POS: NOUN, Dep: dobj, Head: combine
# Token: and, POS: CCONJ, Dep: cc, Head: solutions
# Token: expertise, POS: NOUN, Dep: conj, Head: solutions
# Token: to, POS: PART, Dep: aux, Head: deliver
# Token: deliver, POS: VERB, Dep: advcl, Head: combine
# Token: new, POS: ADJ, Dep: amod, Head: cloud
# Token: cloud, POS: NOUN, Dep: dobj, Head: deliver
# Token: and, POS: CCONJ, Dep: cc, Head: cloud
# Token: AI, POS: PROPN, Dep: compound, Head: capabilities
# Token: capabilities, POS: NOUN, Dep: conj, Head: cloud
# Token: across, POS: ADP, Dep: prep, Head: capabilities
# Token: healthcare, POS: NOUN, Dep: pobj, Head: across
# Token: and, POS: CCONJ, Dep: cc, Head: healthcare
# Token: other, POS: ADJ, Dep: amod, Head: industries
# Token: industries, POS: NOUN, Dep: conj, Head: healthcare
# Token:
#
# , POS: SPACE, Dep: dep, Head: industries
# Token: Microsoft, POS: PROPN, Dep: nmod, Head: REDMOND
# Token: and, POS: CCONJ, Dep: cc, Head: Microsoft
# Token: Nuance, POS: PROPN, Dep: conj, Head: Microsoft
# Token: logos, POS: NOUN, Dep: conj, Head: Microsoft
# Token:
#
# , POS: SPACE, Dep: dep, Head: logos
# Token: REDMOND, POS: PROPN, Dep: appos, Head: healthcare
# Token: ,, POS: PUNCT, Dep: punct, Head: REDMOND
# Token: Wash., POS: PROPN, Dep: conj, Head: REDMOND
# Token: ,, POS: PUNCT, Dep: punct, Head: REDMOND
# Token: and, POS: CCONJ, Dep: cc, Head: REDMOND
# Token: BURLINGTON, POS: PROPN, Dep: nmod, Head: Mass.
# Token: ,, POS: PUNCT, Dep: punct, Head: BURLINGTON
# Token: Mass., POS: PROPN, Dep: conj, Head: combine
# Token: �, POS: PROPN, Dep: nmod, Head: April
# Token: April, POS: PROPN, Dep: npadvmod, Head: combine
# Token: 12, POS: NUM, Dep: nummod, Head: April
# Token: ,, POS: PUNCT, Dep: punct, Head: April
# Token: 2021, POS: NUM, Dep: nummod, Head: April
# Token: �, POS: NOUN, Dep: compound, Head: Corp
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Corp
# Token: Corp, POS: PROPN, Dep: nsubj, Head: announced
# Token: (, POS: PUNCT, Dep: punct, Head: Corp
# Token: Nasdaq, POS: PROPN, Dep: nmod, Head: MSFT
# Token: :, POS: PUNCT, Dep: punct, Head: MSFT
# Token: MSFT, POS: PROPN, Dep: appos, Head: Corp
# Token: ), POS: PUNCT, Dep: punct, Head: MSFT
# Token: and, POS: CCONJ, Dep: cc, Head: MSFT
# Token: Nuance, POS: PROPN, Dep: compound, Head: Communications
# Token: Communications, POS: PROPN, Dep: nmod, Head: Inc.
# Token: ,, POS: PUNCT, Dep: punct, Head: Inc.
# Token: Inc., POS: PROPN, Dep: conj, Head: MSFT
# Token: (, POS: PUNCT, Dep: punct, Head: Corp
# Token: Nasdaq, POS: PROPN, Dep: appos, Head: Corp
# Token: :, POS: PUNCT, Dep: punct, Head: Nasdaq
# Token: NUAN, POS: PROPN, Dep: appos, Head: Nasdaq
# Token: ), POS: PUNCT, Dep: punct, Head: Corp
# Token: today, POS: NOUN, Dep: npadvmod, Head: announced
# Token: announced, POS: VERB, Dep: conj, Head: combine
# Token: they, POS: PRON, Dep: nsubj, Head: entered
# Token: have, POS: AUX, Dep: aux, Head: entered
# Token: entered, POS: VERB, Dep: ccomp, Head: announced
# Token: into, POS: ADP, Dep: prep, Head: entered
# Token: a, POS: DET, Dep: det, Head: agreement
# Token: definitive, POS: ADJ, Dep: amod, Head: agreement
# Token: agreement, POS: NOUN, Dep: pobj, Head: into
# Token: under, POS: ADP, Dep: prep, Head: acquire
# Token: which, POS: PRON, Dep: pobj, Head: under
# Token: Microsoft, POS: PROPN, Dep: nsubj, Head: acquire
# Token: will, POS: AUX, Dep: aux, Head: acquire
# Token: acquire, POS: VERB, Dep: relcl, Head: agreement
# Token: Nuance, POS: PROPN, Dep: dobj, Head: acquire
# Token: for, POS: ADP, Dep: prep, Head: acquire
# Token: $, POS: SYM, Dep: nmod, Head: 56.00
# Token: 56.00, POS: NUM, Dep: pobj, Head: for
# Token: per, POS: ADP, Dep: prep, Head: 56.00
# Token: share, POS: NOUN, Dep: pobj, Head: per
# Token: ,, POS: PUNCT, Dep: punct, Head: acquire
# Token: implying, POS: VERB, Dep: advcl, Head: acquire
# Token: a, POS: DET, Dep: det, Head: premium
# Token: 23, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: compound, Head: premium
# Token: premium, POS: NOUN, Dep: dobj, Head: implying
# Token: to, POS: ADP, Dep: prep, Head: implying
# Token: the, POS: DET, Dep: det, Head: price
# Token: closing, POS: NOUN, Dep: compound, Head: price
# Token: price, POS: NOUN, Dep: pobj, Head: to
# Token: of, POS: ADP, Dep: prep, Head: price
# Token: Nuance, POS: PROPN, Dep: pobj, Head: of
# Token: on, POS: ADP, Dep: prep, Head: price
# Token: Friday, POS: PROPN, Dep: pobj, Head: on
# Token: ,, POS: PUNCT, Dep: punct, Head: Friday
# Token: April, POS: PROPN, Dep: appos, Head: Friday
# Token: 9, POS: NUM, Dep: nummod, Head: April
# Token: ,, POS: PUNCT, Dep: punct, Head: implying
# Token: in, POS: ADP, Dep: prep, Head: implying
# Token: an, POS: DET, Dep: det, Head: transaction
# Token: all, POS: PRON, Dep: advmod, Head: cash
# Token: -, POS: PUNCT, Dep: punct, Head: cash
# Token: cash, POS: NOUN, Dep: compound, Head: transaction
# Token: transaction, POS: NOUN, Dep: pobj, Head: in
# Token: valued, POS: VERB, Dep: acl, Head: transaction
# Token: at, POS: ADP, Dep: prep, Head: valued
# Token: $, POS: SYM, Dep: quantmod, Head: billion
# Token: 19.7, POS: NUM, Dep: compound, Head: billion
# Token: billion, POS: NUM, Dep: pobj, Head: at
# Token: ,, POS: PUNCT, Dep: punct, Head: billion
# Token: inclusive, POS: ADJ, Dep: oprd, Head: valued
# Token: of, POS: ADP, Dep: prep, Head: inclusive
# Token: Nuance, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: X, Dep: nmod, Head: debt
# Token: s, POS: PART, Dep: dep, Head: �
# Token: net, POS: ADJ, Dep: amod, Head: debt
# Token: debt, POS: NOUN, Dep: pobj, Head: of
# Token: ., POS: PUNCT, Dep: punct, Head: announced
#
# Sentence: Nuance is a trusted cloud and AI software leader representing decades of accumulated healthcare and enterprise AI experience.
#
# Token: Nuance, POS: NOUN, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: a, POS: DET, Dep: det, Head: cloud
# Token: trusted, POS: VERB, Dep: amod, Head: cloud
# Token: cloud, POS: NOUN, Dep: attr, Head: is
# Token: and, POS: CCONJ, Dep: cc, Head: cloud
# Token: AI, POS: PROPN, Dep: compound, Head: leader
# Token: software, POS: NOUN, Dep: compound, Head: leader
# Token: leader, POS: NOUN, Dep: conj, Head: cloud
# Token: representing, POS: VERB, Dep: acl, Head: leader
# Token: decades, POS: NOUN, Dep: dobj, Head: representing
# Token: of, POS: ADP, Dep: prep, Head: decades
# Token: accumulated, POS: VERB, Dep: amod, Head: healthcare
# Token: healthcare, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: healthcare
# Token: enterprise, POS: NOUN, Dep: compound, Head: AI
# Token: AI, POS: PROPN, Dep: compound, Head: experience
# Token: experience, POS: NOUN, Dep: conj, Head: healthcare
# Token: ., POS: PUNCT, Dep: punct, Head: is
#
# Sentence: Mark Benjamin will remain CEO of Nuance, reporting to Scott Guthrie, executive vice president of Cloud & AI at Microsoft.
#
# Token: Mark, POS: PROPN, Dep: compound, Head: Benjamin
# Token: Benjamin, POS: PROPN, Dep: nsubj, Head: remain
# Token: will, POS: AUX, Dep: aux, Head: remain
# Token: remain, POS: VERB, Dep: ROOT, Head: remain
# Token: CEO, POS: NOUN, Dep: attr, Head: remain
# Token: of, POS: ADP, Dep: prep, Head: CEO
# Token: Nuance, POS: PROPN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: remain
# Token: reporting, POS: VERB, Dep: advcl, Head: remain
# Token: to, POS: ADP, Dep: prep, Head: reporting
# Token: Scott, POS: PROPN, Dep: compound, Head: Guthrie
# Token: Guthrie, POS: PROPN, Dep: pobj, Head: to
# Token: ,, POS: PUNCT, Dep: punct, Head: Guthrie
# Token: executive, POS: ADJ, Dep: amod, Head: president
# Token: vice, POS: NOUN, Dep: compound, Head: president
# Token: president, POS: NOUN, Dep: appos, Head: Guthrie
# Token: of, POS: ADP, Dep: prep, Head: president
# Token: Cloud, POS: PROPN, Dep: pobj, Head: of
# Token: &, POS: CCONJ, Dep: cc, Head: Cloud
# Token: AI, POS: PROPN, Dep: conj, Head: Cloud
# Token: at, POS: ADP, Dep: prep, Head: president
# Token: Microsoft, POS: PROPN, Dep: pobj, Head: at
# Token: ., POS: PUNCT, Dep: punct, Head: remain
#
# Sentence: The transaction is intended to close this calendar year.
#
#
#
# Token: The, POS: DET, Dep: det, Head: transaction
# Token: transaction, POS: NOUN, Dep: nsubjpass, Head: intended
# Token: is, POS: AUX, Dep: auxpass, Head: intended
# Token: intended, POS: VERB, Dep: ROOT, Head: intended
# Token: to, POS: PART, Dep: aux, Head: close
# Token: close, POS: VERB, Dep: xcomp, Head: intended
# Token: this, POS: DET, Dep: det, Head: year
# Token: calendar, POS: NOUN, Dep: compound, Head: year
# Token: year, POS: NOUN, Dep: npadvmod, Head: close
# Token: ., POS: PUNCT, Dep: punct, Head: intended
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Microsoft has accelerated its efforts to provide industry-specific cloud offerings to support customers and partners as they respond to disruption and new opportunities.
#
# Token: Microsoft, POS: PROPN, Dep: nsubj, Head: accelerated
# Token: has, POS: AUX, Dep: aux, Head: accelerated
# Token: accelerated, POS: VERB, Dep: ROOT, Head: accelerated
# Token: its, POS: PRON, Dep: poss, Head: efforts
# Token: efforts, POS: NOUN, Dep: dobj, Head: accelerated
# Token: to, POS: PART, Dep: aux, Head: provide
# Token: provide, POS: VERB, Dep: acl, Head: efforts
# Token: industry, POS: NOUN, Dep: npadvmod, Head: specific
# Token: -, POS: PUNCT, Dep: punct, Head: specific
# Token: specific, POS: ADJ, Dep: amod, Head: offerings
# Token: cloud, POS: ADJ, Dep: amod, Head: offerings
# Token: offerings, POS: NOUN, Dep: dobj, Head: provide
# Token: to, POS: PART, Dep: aux, Head: support
# Token: support, POS: VERB, Dep: advcl, Head: provide
# Token: customers, POS: NOUN, Dep: dobj, Head: support
# Token: and, POS: CCONJ, Dep: cc, Head: customers
# Token: partners, POS: NOUN, Dep: conj, Head: customers
# Token: as, POS: SCONJ, Dep: mark, Head: respond
# Token: they, POS: PRON, Dep: nsubj, Head: respond
# Token: respond, POS: VERB, Dep: advcl, Head: support
# Token: to, POS: ADP, Dep: prep, Head: respond
# Token: disruption, POS: NOUN, Dep: pobj, Head: to
# Token: and, POS: CCONJ, Dep: cc, Head: disruption
# Token: new, POS: ADJ, Dep: amod, Head: opportunities
# Token: opportunities, POS: NOUN, Dep: conj, Head: disruption
# Token: ., POS: PUNCT, Dep: punct, Head: accelerated
#
# Sentence: These efforts include the Microsoft Cloud for Healthcare, introduced in 2020, which aims to address the comprehensive needs of the rapidly transforming and growing healthcare industry.
#
# Token: These, POS: DET, Dep: det, Head: efforts
# Token: efforts, POS: NOUN, Dep: nsubj, Head: include
# Token: include, POS: VERB, Dep: ROOT, Head: include
# Token: the, POS: DET, Dep: det, Head: Cloud
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Cloud
# Token: Cloud, POS: PROPN, Dep: dobj, Head: include
# Token: for, POS: ADP, Dep: prep, Head: Cloud
# Token: Healthcare, POS: PROPN, Dep: pobj, Head: for
# Token: ,, POS: PUNCT, Dep: punct, Head: Cloud
# Token: introduced, POS: VERB, Dep: acl, Head: Cloud
# Token: in, POS: ADP, Dep: prep, Head: introduced
# Token: 2020, POS: NUM, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: Cloud
# Token: which, POS: PRON, Dep: nsubj, Head: aims
# Token: aims, POS: VERB, Dep: relcl, Head: Cloud
# Token: to, POS: PART, Dep: aux, Head: address
# Token: address, POS: VERB, Dep: xcomp, Head: aims
# Token: the, POS: DET, Dep: det, Head: needs
# Token: comprehensive, POS: ADJ, Dep: amod, Head: needs
# Token: needs, POS: NOUN, Dep: dobj, Head: address
# Token: of, POS: ADP, Dep: prep, Head: needs
# Token: the, POS: DET, Dep: det, Head: transforming
# Token: rapidly, POS: ADV, Dep: advmod, Head: transforming
# Token: transforming, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: transforming
# Token: growing, POS: VERB, Dep: amod, Head: industry
# Token: healthcare, POS: NOUN, Dep: compound, Head: industry
# Token: industry, POS: NOUN, Dep: conj, Head: transforming
# Token: ., POS: PUNCT, Dep: punct, Head: include
#
# Sentence: Today�s acquisition announcement represents the latest step in Microsoft�s industry-specific cloud strategy.
#
#
#
# Token: Today, POS: NOUN, Dep: compound, Head: �
# Token: �, POS: PROPN, Dep: poss, Head: announcement
# Token: s, POS: PART, Dep: case, Head: �
# Token: acquisition, POS: NOUN, Dep: compound, Head: announcement
# Token: announcement, POS: NOUN, Dep: nsubj, Head: represents
# Token: represents, POS: VERB, Dep: ROOT, Head: represents
# Token: the, POS: DET, Dep: det, Head: step
# Token: latest, POS: ADJ, Dep: amod, Head: step
# Token: step, POS: NOUN, Dep: dobj, Head: represents
# Token: in, POS: ADP, Dep: prep, Head: step
# Token: Microsoft, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: NOUN, Dep: nmod, Head: strategy
# Token: s, POS: PART, Dep: case, Head: �
# Token: industry, POS: NOUN, Dep: npadvmod, Head: specific
# Token: -, POS: PUNCT, Dep: punct, Head: specific
# Token: specific, POS: ADJ, Dep: amod, Head: strategy
# Token: cloud, POS: NOUN, Dep: compound, Head: strategy
# Token: strategy, POS: NOUN, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: represents
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Nuance is a pioneer and a leading provider of conversational AI and cloud-based ambient clinical intelligence for healthcare providers.
#
# Token: Nuance, POS: PROPN, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: a, POS: DET, Dep: det, Head: pioneer
# Token: pioneer, POS: NOUN, Dep: attr, Head: is
# Token: and, POS: CCONJ, Dep: cc, Head: pioneer
# Token: a, POS: DET, Dep: det, Head: provider
# Token: leading, POS: VERB, Dep: amod, Head: provider
# Token: provider, POS: NOUN, Dep: conj, Head: pioneer
# Token: of, POS: ADP, Dep: prep, Head: provider
# Token: conversational, POS: ADJ, Dep: amod, Head: AI
# Token: AI, POS: PROPN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: AI
# Token: cloud, POS: PROPN, Dep: npadvmod, Head: based
# Token: -, POS: PUNCT, Dep: punct, Head: based
# Token: based, POS: VERB, Dep: amod, Head: intelligence
# Token: ambient, POS: NOUN, Dep: nmod, Head: intelligence
# Token: clinical, POS: ADJ, Dep: amod, Head: intelligence
# Token: intelligence, POS: NOUN, Dep: conj, Head: AI
# Token: for, POS: ADP, Dep: prep, Head: intelligence
# Token: healthcare, POS: NOUN, Dep: compound, Head: providers
# Token: providers, POS: NOUN, Dep: pobj, Head: for
# Token: ., POS: PUNCT, Dep: punct, Head: is
#
# Sentence: Nuance�s products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.
#
# Token: Nuance, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: NOUN, Dep: compound, Head: s
# Token: s, POS: PART, Dep: compound, Head: products
# Token: products, POS: NOUN, Dep: nsubj, Head: include
# Token: include, POS: VERB, Dep: ROOT, Head: include
# Token: the, POS: DET, Dep: det, Head: eXperience
# Token: Dragon, POS: PROPN, Dep: compound, Head: eXperience
# Token: Ambient, POS: PROPN, Dep: compound, Head: eXperience
# Token: eXperience, POS: PROPN, Dep: dobj, Head: include
# Token: ,, POS: PUNCT, Dep: punct, Head: eXperience
# Token: Dragon, POS: PROPN, Dep: compound, Head: One
# Token: Medical, POS: PROPN, Dep: compound, Head: One
# Token: One, POS: PROPN, Dep: conj, Head: eXperience
# Token: and, POS: CCONJ, Dep: cc, Head: One
# Token: PowerScribe, POS: PROPN, Dep: conj, Head: One
# Token: One, POS: NUM, Dep: nummod, Head: PowerScribe
# Token: for, POS: ADP, Dep: prep, Head: eXperience
# Token: radiology, POS: NOUN, Dep: compound, Head: reporting
# Token: reporting, POS: NOUN, Dep: pobj, Head: for
# Token: ,, POS: PUNCT, Dep: punct, Head: eXperience
# Token: all, POS: DET, Dep: det, Head: offerings
# Token: leading, POS: VERB, Dep: amod, Head: SaaS
# Token: clinical, POS: ADJ, Dep: amod, Head: speech
# Token: speech, POS: NOUN, Dep: compound, Head: recognition
# Token: recognition, POS: NOUN, Dep: compound, Head: SaaS
# Token: SaaS, POS: PROPN, Dep: compound, Head: offerings
# Token: offerings, POS: NOUN, Dep: appos, Head: eXperience
# Token: built, POS: VERB, Dep: acl, Head: offerings
# Token: on, POS: ADP, Dep: prep, Head: built
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Azure
# Token: Azure, POS: PROPN, Dep: pobj, Head: on
# Token: ., POS: PUNCT, Dep: punct, Head: include
#
# Sentence: Nuance�s solutions work seamlessly with core healthcare systems, including longstanding relationships with Electronic Health Records (EHRs), to alleviate the burden of clinical documentation and empower providers to deliver better patient experiences.
#
# Token: Nuance, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: NOUN, Dep: compound, Head: s
# Token: s, POS: NOUN, Dep: compound, Head: solutions
# Token: solutions, POS: NOUN, Dep: nsubj, Head: work
# Token: work, POS: VERB, Dep: ROOT, Head: work
# Token: seamlessly, POS: ADV, Dep: advmod, Head: work
# Token: with, POS: ADP, Dep: prep, Head: work
# Token: core, POS: NOUN, Dep: compound, Head: systems
# Token: healthcare, POS: NOUN, Dep: compound, Head: systems
# Token: systems, POS: NOUN, Dep: pobj, Head: with
# Token: ,, POS: PUNCT, Dep: punct, Head: systems
# Token: including, POS: VERB, Dep: prep, Head: systems
# Token: longstanding, POS: ADJ, Dep: amod, Head: relationships
# Token: relationships, POS: NOUN, Dep: pobj, Head: including
# Token: with, POS: ADP, Dep: prep, Head: relationships
# Token: Electronic, POS: PROPN, Dep: compound, Head: Records
# Token: Health, POS: PROPN, Dep: compound, Head: Records
# Token: Records, POS: PROPN, Dep: pobj, Head: with
# Token: (, POS: PUNCT, Dep: punct, Head: Records
# Token: EHRs, POS: PROPN, Dep: appos, Head: Records
# Token: ), POS: PUNCT, Dep: punct, Head: Records
# Token: ,, POS: PUNCT, Dep: punct, Head: work
# Token: to, POS: PART, Dep: aux, Head: alleviate
# Token: alleviate, POS: VERB, Dep: advcl, Head: work
# Token: the, POS: DET, Dep: det, Head: burden
# Token: burden, POS: NOUN, Dep: dobj, Head: alleviate
# Token: of, POS: ADP, Dep: prep, Head: burden
# Token: clinical, POS: ADJ, Dep: amod, Head: documentation
# Token: documentation, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: alleviate
# Token: empower, POS: VERB, Dep: conj, Head: alleviate
# Token: providers, POS: NOUN, Dep: dobj, Head: empower
# Token: to, POS: PART, Dep: aux, Head: deliver
# Token: deliver, POS: VERB, Dep: xcomp, Head: empower
# Token: better, POS: ADJ, Dep: amod, Head: experiences
# Token: patient, POS: ADJ, Dep: amod, Head: experiences
# Token: experiences, POS: NOUN, Dep: dobj, Head: deliver
# Token: ., POS: PUNCT, Dep: punct, Head: work
#
# Sentence: Nuance solutions are currently used by more than 55% of physicians and 75% of radiologists in the U.S., and used in 77% of U.S. hospitals.
#
# Token: Nuance, POS: NOUN, Dep: compound, Head: solutions
# Token: solutions, POS: NOUN, Dep: nsubjpass, Head: used
# Token: are, POS: AUX, Dep: auxpass, Head: used
# Token: currently, POS: ADV, Dep: advmod, Head: used
# Token: used, POS: VERB, Dep: ROOT, Head: used
# Token: by, POS: ADP, Dep: agent, Head: used
# Token: more, POS: ADJ, Dep: amod, Head: 55
# Token: than, POS: ADP, Dep: quantmod, Head: 55
# Token: 55, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: pobj, Head: by
# Token: of, POS: ADP, Dep: prep, Head: %
# Token: physicians, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: %
# Token: 75, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: conj, Head: %
# Token: of, POS: ADP, Dep: prep, Head: %
# Token: radiologists, POS: NOUN, Dep: pobj, Head: of
# Token: in, POS: ADP, Dep: prep, Head: radiologists
# Token: the, POS: DET, Dep: det, Head: U.S.
# Token: U.S., POS: PROPN, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: used
# Token: and, POS: CCONJ, Dep: cc, Head: used
# Token: used, POS: VERB, Dep: conj, Head: used
# Token: in, POS: ADP, Dep: prep, Head: used
# Token: 77, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: pobj, Head: in
# Token: of, POS: ADP, Dep: prep, Head: %
# Token: U.S., POS: PROPN, Dep: compound, Head: hospitals
# Token: hospitals, POS: NOUN, Dep: pobj, Head: of
# Token: ., POS: PUNCT, Dep: punct, Head: used
#
# Sentence: Nuance�s Healthcare Cloud revenue experienced 37% year-over-year growth in Nuance�s fiscal year 2020 (ended September 2020).
#
#
#
# Token: Nuance, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: X, Dep: nmod, Head: revenue
# Token: s, POS: PROPN, Dep: case, Head: �
# Token: Healthcare, POS: PROPN, Dep: compound, Head: Cloud
# Token: Cloud, POS: PROPN, Dep: compound, Head: revenue
# Token: revenue, POS: NOUN, Dep: nsubj, Head: experienced
# Token: experienced, POS: VERB, Dep: ROOT, Head: experienced
# Token: 37, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: nmod, Head: growth
# Token: year, POS: NOUN, Dep: nmod, Head: growth
# Token: -, POS: PUNCT, Dep: punct, Head: year
# Token: over, POS: ADP, Dep: prep, Head: year
# Token: -, POS: PUNCT, Dep: punct, Head: over
# Token: year, POS: NOUN, Dep: pobj, Head: over
# Token: growth, POS: NOUN, Dep: dobj, Head: experienced
# Token: in, POS: ADP, Dep: prep, Head: growth
# Token: Nuance, POS: PROPN, Dep: pobj, Head: in
# Token: �, POS: NOUN, Dep: nmod, Head: Nuance
# Token: s, POS: PART, Dep: case, Head: �
# Token: fiscal, POS: ADJ, Dep: amod, Head: year
# Token: year, POS: NOUN, Dep: npadvmod, Head: Nuance
# Token: 2020, POS: NUM, Dep: nummod, Head: year
# Token: (, POS: PUNCT, Dep: punct, Head: ended
# Token: ended, POS: VERB, Dep: parataxis, Head: experienced
# Token: September, POS: PROPN, Dep: npadvmod, Head: ended
# Token: 2020, POS: NUM, Dep: nummod, Head: September
# Token: ), POS: PUNCT, Dep: punct, Head: ended
# Token: ., POS: PUNCT, Dep: punct, Head: experienced
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Microsoft�s acquisition of Nuance builds upon the successful existing partnership between the companies that was announced in 2019.
#
# Token: Microsoft, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: NOUN, Dep: poss, Head: acquisition
# Token: s, POS: PART, Dep: case, Head: �
# Token: acquisition, POS: NOUN, Dep: nsubj, Head: builds
# Token: of, POS: ADP, Dep: prep, Head: acquisition
# Token: Nuance, POS: PROPN, Dep: pobj, Head: of
# Token: builds, POS: VERB, Dep: ROOT, Head: builds
# Token: upon, POS: SCONJ, Dep: prep, Head: builds
# Token: the, POS: DET, Dep: det, Head: partnership
# Token: successful, POS: ADJ, Dep: amod, Head: partnership
# Token: existing, POS: VERB, Dep: amod, Head: partnership
# Token: partnership, POS: NOUN, Dep: pobj, Head: upon
# Token: between, POS: ADP, Dep: prep, Head: partnership
# Token: the, POS: DET, Dep: det, Head: companies
# Token: companies, POS: NOUN, Dep: pobj, Head: between
# Token: that, POS: PRON, Dep: nsubjpass, Head: announced
# Token: was, POS: AUX, Dep: auxpass, Head: announced
# Token: announced, POS: VERB, Dep: relcl, Head: companies
# Token: in, POS: ADP, Dep: prep, Head: announced
# Token: 2019, POS: NUM, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: builds
#
# Sentence: By augmenting the Microsoft Cloud for Healthcare with Nuance�s solutions, as well as the benefit of Nuance�s expertise and relationships with EHR systems providers, Microsoft will be better able to empower healthcare providers through the power of ambient clinical intelligence and other Microsoft cloud services.
#
# Token: By, POS: ADP, Dep: prep, Head: be
# Token: augmenting, POS: VERB, Dep: pcomp, Head: By
# Token: the, POS: DET, Dep: det, Head: Cloud
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Cloud
# Token: Cloud, POS: PROPN, Dep: dobj, Head: augmenting
# Token: for, POS: ADP, Dep: prep, Head: augmenting
# Token: Healthcare, POS: PROPN, Dep: pobj, Head: for
# Token: with, POS: ADP, Dep: prep, Head: augmenting
# Token: Nuance, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: NOUN, Dep: nmod, Head: solutions
# Token: s, POS: NOUN, Dep: compound, Head: solutions
# Token: solutions, POS: NOUN, Dep: pobj, Head: with
# Token: ,, POS: PUNCT, Dep: punct, Head: By
# Token: as, POS: ADV, Dep: advmod, Head: as
# Token: well, POS: ADV, Dep: advmod, Head: as
# Token: as, POS: ADP, Dep: cc, Head: By
# Token: the, POS: DET, Dep: det, Head: benefit
# Token: benefit, POS: NOUN, Dep: pobj, Head: By
# Token: of, POS: ADP, Dep: prep, Head: benefit
# Token: Nuance, POS: PROPN, Dep: compound, Head: �
# Token: �, POS: NOUN, Dep: compound, Head: s
# Token: s, POS: NOUN, Dep: compound, Head: expertise
# Token: expertise, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: expertise
# Token: relationships, POS: NOUN, Dep: conj, Head: expertise
# Token: with, POS: ADP, Dep: prep, Head: benefit
# Token: EHR, POS: PROPN, Dep: compound, Head: systems
# Token: systems, POS: NOUN, Dep: compound, Head: providers
# Token: providers, POS: NOUN, Dep: pobj, Head: with
# Token: ,, POS: PUNCT, Dep: punct, Head: be
# Token: Microsoft, POS: PROPN, Dep: nsubj, Head: be
# Token: will, POS: AUX, Dep: aux, Head: be
# Token: be, POS: AUX, Dep: ROOT, Head: be
# Token: better, POS: ADV, Dep: advmod, Head: able
# Token: able, POS: ADJ, Dep: acomp, Head: be
# Token: to, POS: PART, Dep: aux, Head: empower
# Token: empower, POS: VERB, Dep: xcomp, Head: able
# Token: healthcare, POS: NOUN, Dep: compound, Head: providers
# Token: providers, POS: NOUN, Dep: dobj, Head: empower
# Token: through, POS: ADP, Dep: prep, Head: empower
# Token: the, POS: DET, Dep: det, Head: power
# Token: power, POS: NOUN, Dep: pobj, Head: through
# Token: of, POS: ADP, Dep: prep, Head: power
# Token: ambient, POS: ADJ, Dep: amod, Head: intelligence
# Token: clinical, POS: ADJ, Dep: amod, Head: intelligence
# Token: intelligence, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: intelligence
# Token: other, POS: ADJ, Dep: amod, Head: services
# Token: Microsoft, POS: PROPN, Dep: compound, Head: services
# Token: cloud, POS: NOUN, Dep: compound, Head: services
# Token: services, POS: NOUN, Dep: conj, Head: intelligence
# Token: ., POS: PUNCT, Dep: punct, Head: be
#
# Sentence: The acquisition will double Microsoft�s total addressable market (TAM) in the healthcare provider space, bringing the company�s TAM in healthcare to nearly $500 billion.
#
# Token: The, POS: DET, Dep: det, Head: acquisition
# Token: acquisition, POS: NOUN, Dep: nsubj, Head: double
# Token: will, POS: AUX, Dep: aux, Head: double
# Token: double, POS: VERB, Dep: ROOT, Head: double
# Token: Microsoft, POS: PROPN, Dep: nmod, Head: market
# Token: �, POS: NOUN, Dep: appos, Head: Microsoft
# Token: s, POS: PART, Dep: case, Head: �
# Token: total, POS: ADJ, Dep: amod, Head: market
# Token: addressable, POS: ADJ, Dep: amod, Head: market
# Token: market, POS: NOUN, Dep: dobj, Head: double
# Token: (, POS: PUNCT, Dep: punct, Head: market
# Token: TAM, POS: PROPN, Dep: appos, Head: market
# Token: ), POS: PUNCT, Dep: punct, Head: TAM
# Token: in, POS: ADP, Dep: prep, Head: double
# Token: the, POS: DET, Dep: det, Head: space
# Token: healthcare, POS: NOUN, Dep: compound, Head: provider
# Token: provider, POS: NOUN, Dep: compound, Head: space
# Token: space, POS: NOUN, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: double
# Token: bringing, POS: VERB, Dep: advcl, Head: double
# Token: the, POS: DET, Dep: det, Head: company
# Token: company, POS: NOUN, Dep: dobj, Head: bringing
# Token: �, POS: NOUN, Dep: dobj, Head: bringing
# Token: s, POS: VERB, Dep: dobj, Head: bringing
# Token: TAM, POS: PROPN, Dep: dobj, Head: bringing
# Token: in, POS: ADP, Dep: prep, Head: bringing
# Token: healthcare, POS: NOUN, Dep: pobj, Head: in
# Token: to, POS: ADP, Dep: prep, Head: bringing
# Token: nearly, POS: ADV, Dep: advmod, Head: billion
# Token: $, POS: SYM, Dep: quantmod, Head: billion
# Token: 500, POS: NUM, Dep: compound, Head: billion
# Token: billion, POS: NUM, Dep: pobj, Head: to
# Token: ., POS: PUNCT, Dep: punct, Head: double
#
# Sentence: Nuance and Microsoft will deepen their existing commitments to the extended partner ecosystem, as well as the highest standards of data privacy, security and compliance.
#
#
#
# Token: Nuance, POS: PROPN, Dep: nsubj, Head: deepen
# Token: and, POS: CCONJ, Dep: cc, Head: Nuance
# Token: Microsoft, POS: PROPN, Dep: conj, Head: Nuance
# Token: will, POS: AUX, Dep: aux, Head: deepen
# Token: deepen, POS: VERB, Dep: ROOT, Head: deepen
# Token: their, POS: PRON, Dep: poss, Head: commitments
# Token: existing, POS: VERB, Dep: amod, Head: commitments
# Token: commitments, POS: NOUN, Dep: dobj, Head: deepen
# Token: to, POS: ADP, Dep: prep, Head: deepen
# Token: the, POS: DET, Dep: det, Head: ecosystem
# Token: extended, POS: ADJ, Dep: amod, Head: ecosystem
# Token: partner, POS: NOUN, Dep: compound, Head: ecosystem
# Token: ecosystem, POS: NOUN, Dep: pobj, Head: to
# Token: ,, POS: PUNCT, Dep: punct, Head: deepen
# Token: as, POS: ADV, Dep: advmod, Head: as
# Token: well, POS: ADV, Dep: advmod, Head: as
# Token: as, POS: ADP, Dep: cc, Head: deepen
# Token: the, POS: DET, Dep: det, Head: standards
# Token: highest, POS: ADJ, Dep: amod, Head: standards
# Token: standards, POS: NOUN, Dep: dobj, Head: deepen
# Token: of, POS: ADP, Dep: prep, Head: standards
# Token: data, POS: NOUN, Dep: compound, Head: privacy
# Token: privacy, POS: NOUN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: privacy
# Token: security, POS: NOUN, Dep: conj, Head: privacy
# Token: and, POS: CCONJ, Dep: cc, Head: security
# Token: compliance, POS: NOUN, Dep: conj, Head: security
# Token: ., POS: PUNCT, Dep: punct, Head: deepen
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: �Nuance provides the AI layer at the healthcare point of delivery and is a pioneer in the real-world application of enterprise AI,� said Satya Nadella, CEO, Microsoft.
#
# Token: �, POS: ADP, Dep: dep, Head: provides
# Token: Nuance, POS: PROPN, Dep: nsubj, Head: provides
# Token: provides, POS: VERB, Dep: ccomp, Head: said
# Token: the, POS: DET, Dep: det, Head: layer
# Token: AI, POS: PROPN, Dep: compound, Head: layer
# Token: layer, POS: NOUN, Dep: dobj, Head: provides
# Token: at, POS: ADP, Dep: prep, Head: provides
# Token: the, POS: DET, Dep: det, Head: point
# Token: healthcare, POS: NOUN, Dep: compound, Head: point
# Token: point, POS: NOUN, Dep: pobj, Head: at
# Token: of, POS: ADP, Dep: prep, Head: point
# Token: delivery, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: provides
# Token: is, POS: AUX, Dep: conj, Head: provides
# Token: a, POS: DET, Dep: det, Head: pioneer
# Token: pioneer, POS: NOUN, Dep: attr, Head: is
# Token: in, POS: ADP, Dep: prep, Head: pioneer
# Token: the, POS: DET, Dep: det, Head: application
# Token: real, POS: ADJ, Dep: amod, Head: world
# Token: -, POS: PUNCT, Dep: punct, Head: world
# Token: world, POS: NOUN, Dep: compound, Head: application
# Token: application, POS: NOUN, Dep: pobj, Head: in
# Token: of, POS: ADP, Dep: prep, Head: application
# Token: enterprise, POS: NOUN, Dep: compound, Head: AI
# Token: AI, POS: PROPN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: said
# Token: �, POS: NOUN, Dep: nsubj, Head: said
# Token: said, POS: VERB, Dep: ROOT, Head: said
# Token: Satya, POS: PROPN, Dep: compound, Head: Nadella
# Token: Nadella, POS: PROPN, Dep: nsubj, Head: said
# Token: ,, POS: PUNCT, Dep: punct, Head: Nadella
# Token: CEO, POS: PROPN, Dep: appos, Head: Nadella
# Token: ,, POS: PUNCT, Dep: punct, Head: CEO
# Token: Microsoft, POS: PROPN, Dep: npadvmod, Head: CEO
# Token: ., POS: PUNCT, Dep: punct, Head: said
#
# Sentence: �AI is technology�s most important priority, and healthcare is its most urgent application.
#
# Token: �, POS: PROPN, Dep: nsubj, Head: is
# Token: AI, POS: PROPN, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: technology, POS: NOUN, Dep: compound, Head: �
# Token: �, POS: X, Dep: poss, Head: priority
# Token: s, POS: PART, Dep: case, Head: �
# Token: most, POS: ADV, Dep: advmod, Head: important
# Token: important, POS: ADJ, Dep: amod, Head: priority
# Token: priority, POS: NOUN, Dep: attr, Head: is
# Token: ,, POS: PUNCT, Dep: punct, Head: is
# Token: and, POS: CCONJ, Dep: cc, Head: is
# Token: healthcare, POS: NOUN, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: conj, Head: is
# Token: its, POS: PRON, Dep: poss, Head: application
# Token: most, POS: ADV, Dep: advmod, Head: urgent
# Token: urgent, POS: ADJ, Dep: amod, Head: application
# Token: application, POS: NOUN, Dep: attr, Head: is
# Token: ., POS: PUNCT, Dep: punct, Head: is
#
# Sentence: Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.
#
# Token: Together, POS: ADV, Dep: advmod, Head: put
# Token: ,, POS: PUNCT, Dep: punct, Head: put
# Token: with, POS: ADP, Dep: prep, Head: put
# Token: our, POS: PRON, Dep: poss, Head: ecosystem
# Token: partner, POS: NOUN, Dep: compound, Head: ecosystem
# Token: ecosystem, POS: NOUN, Dep: pobj, Head: with
# Token: ,, POS: PUNCT, Dep: punct, Head: put
# Token: we, POS: PRON, Dep: nsubj, Head: put
# Token: will, POS: AUX, Dep: aux, Head: put
# Token: put, POS: VERB, Dep: ROOT, Head: put
# Token: advanced, POS: ADJ, Dep: amod, Head: solutions
# Token: AI, POS: PROPN, Dep: compound, Head: solutions
# Token: solutions, POS: NOUN, Dep: dobj, Head: put
# Token: into, POS: ADP, Dep: prep, Head: put
# Token: the, POS: DET, Dep: det, Head: hands
# Token: hands, POS: NOUN, Dep: pobj, Head: into
# Token: of, POS: ADP, Dep: prep, Head: hands
# Token: professionals, POS: NOUN, Dep: pobj, Head: of
# Token: everywhere, POS: ADV, Dep: advmod, Head: professionals
# Token: to, POS: PART, Dep: aux, Head: drive
# Token: drive, POS: VERB, Dep: advcl, Head: put
# Token: better, POS: ADJ, Dep: amod, Head: making
# Token: decision, POS: NOUN, Dep: compound, Head: making
# Token: -, POS: PUNCT, Dep: punct, Head: making
# Token: making, POS: NOUN, Dep: dobj, Head: drive
# Token: and, POS: CCONJ, Dep: cc, Head: drive
# Token: create, POS: VERB, Dep: conj, Head: drive
# Token: more, POS: ADV, Dep: advmod, Head: meaningful
# Token: meaningful, POS: ADJ, Dep: amod, Head: connections
# Token: connections, POS: NOUN, Dep: dobj, Head: create
# Token: ,, POS: PUNCT, Dep: punct, Head: put
# Token: as, POS: SCONJ, Dep: mark, Head: accelerate
# Token: we, POS: PRON, Dep: nsubj, Head: accelerate
# Token: accelerate, POS: VERB, Dep: advcl, Head: put
# Token: growth, POS: NOUN, Dep: dobj, Head: accelerate
# Token: of, POS: ADP, Dep: prep, Head: growth
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Cloud
# Token: Cloud, POS: PROPN, Dep: pobj, Head: of
# Token: for, POS: ADP, Dep: prep, Head: growth
# Token: Healthcare, POS: PROPN, Dep: pobj, Head: for
# Token: and, POS: CCONJ, Dep: cc, Head: Healthcare
# Token: Nuance, POS: PROPN, Dep: conj, Head: Healthcare
# Token: ., POS: PUNCT, Dep: punct, Head: put
#
# Sentence: �
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.
#
# Token: �, POS: PROPN, Dep: dep, Head: provides
# Token:
#
# , POS: SPACE, Dep: dep, Head: �
# Token: Beyond, POS: ADP, Dep: prep, Head: �
# Token: healthcare, POS: NOUN, Dep: pobj, Head: Beyond
# Token: ,, POS: PUNCT, Dep: punct, Head: provides
# Token: Nuance, POS: PROPN, Dep: nsubj, Head: provides
# Token: provides, POS: VERB, Dep: ROOT, Head: provides
# Token: AI, POS: PROPN, Dep: compound, Head: expertise
# Token: expertise, POS: NOUN, Dep: nmod, Head: solutions
# Token: and, POS: CCONJ, Dep: cc, Head: expertise
# Token: customer, POS: NOUN, Dep: compound, Head: engagement
# Token: engagement, POS: NOUN, Dep: compound, Head: solutions
# Token: solutions, POS: NOUN, Dep: dobj, Head: provides
# Token: across, POS: ADP, Dep: prep, Head: solutions
# Token: Interactive, POS: PROPN, Dep: compound, Head: Response
# Token: Voice, POS: PROPN, Dep: compound, Head: Response
# Token: Response, POS: PROPN, Dep: pobj, Head: across
# Token: (, POS: PUNCT, Dep: punct, Head: Response
# Token: IVR, POS: PROPN, Dep: appos, Head: Response
# Token: ), POS: PUNCT, Dep: punct, Head: Response
# Token: ,, POS: PUNCT, Dep: punct, Head: Response
# Token: virtual, POS: ADJ, Dep: amod, Head: assistants
# Token: assistants, POS: NOUN, Dep: conj, Head: Response
# Token: ,, POS: PUNCT, Dep: punct, Head: assistants
# Token: and, POS: CCONJ, Dep: cc, Head: assistants
# Token: digital, POS: ADJ, Dep: amod, Head: solutions
# ...
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: About Nuance Communications, Inc.
# Nuance Communications (NASDAQ: NUAN) is a technology pioneer with market leadership in conversational AI and ambient intelligence.
#
# Token: About, POS: ADP, Dep: nsubj, Head: is
# Token: Nuance, POS: PROPN, Dep: compound, Head: Communications
# Token: Communications, POS: PROPN, Dep: pobj, Head: About
# Token: ,, POS: PUNCT, Dep: punct, Head: Communications
# Token: Inc., POS: PROPN, Dep: compound, Head: Communications
# Token:
# , POS: SPACE, Dep: dep, Head: Inc.
# Token: Nuance, POS: PROPN, Dep: compound, Head: Communications
# Token: Communications, POS: PROPN, Dep: conj, Head: Communications
# Token: (, POS: PUNCT, Dep: punct, Head: Communications
# Token: NASDAQ, POS: PROPN, Dep: appos, Head: Communications
# Token: :, POS: PUNCT, Dep: punct, Head: NASDAQ
# Token: NUAN, POS: PROPN, Dep: appos, Head: NASDAQ
# Token: ), POS: PUNCT, Dep: punct, Head: Communications
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: a, POS: DET, Dep: det, Head: pioneer
# Token: technology, POS: NOUN, Dep: compound, Head: pioneer
# Token: pioneer, POS: NOUN, Dep: attr, Head: is
# Token: with, POS: ADP, Dep: prep, Head: pioneer
# Token: market, POS: NOUN, Dep: compound, Head: leadership
# Token: leadership, POS: NOUN, Dep: pobj, Head: with
# Token: in, POS: ADP, Dep: prep, Head: leadership
# Token: conversational, POS: ADJ, Dep: amod, Head: AI
# Token: AI, POS: PROPN, Dep: pobj, Head: in
# Token: and, POS: CCONJ, Dep: cc, Head: AI
# Token: ambient, POS: ADJ, Dep: amod, Head: intelligence
# Token: intelligence, POS: NOUN, Dep: conj, Head: AI
# Token: ., POS: PUNCT, Dep: punct, Head: is
#
# Sentence: A full-service partner trusted by 77 percent of U.S. hospitals and 85 percent of the Fortune 100 companies worldwide, Nuance creates intuitive solutions that amplify people�s ability to help others.
#
#
#
# Token: A, POS: DET, Dep: det, Head: partner
# Token: full, POS: ADJ, Dep: amod, Head: service
# Token: -, POS: PUNCT, Dep: punct, Head: service
# Token: service, POS: NOUN, Dep: compound, Head: partner
# Token: partner, POS: NOUN, Dep: nsubj, Head: creates
# Token: trusted, POS: VERB, Dep: acl, Head: partner
# Token: by, POS: ADP, Dep: agent, Head: trusted
# Token: 77, POS: NUM, Dep: nummod, Head: percent
# Token: percent, POS: NOUN, Dep: pobj, Head: by
# Token: of, POS: ADP, Dep: prep, Head: percent
# Token: U.S., POS: PROPN, Dep: compound, Head: hospitals
# Token: hospitals, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: percent
# Token: 85, POS: NUM, Dep: nummod, Head: percent
# Token: percent, POS: NOUN, Dep: conj, Head: percent
# Token: of, POS: ADP, Dep: prep, Head: percent
# Token: the, POS: DET, Dep: det, Head: companies
# Token: Fortune, POS: PROPN, Dep: nmod, Head: companies
# Token: 100, POS: NUM, Dep: nummod, Head: companies
# Token: companies, POS: NOUN, Dep: pobj, Head: of
# Token: worldwide, POS: ADV, Dep: advmod, Head: companies
# Token: ,, POS: PUNCT, Dep: punct, Head: creates
# Token: Nuance, POS: PROPN, Dep: nsubj, Head: creates
# Token: creates, POS: VERB, Dep: ROOT, Head: creates
# Token: intuitive, POS: ADJ, Dep: amod, Head: solutions
# Token: solutions, POS: NOUN, Dep: dobj, Head: creates
# Token: that, POS: PRON, Dep: nsubj, Head: amplify
# Token: amplify, POS: VERB, Dep: relcl, Head: solutions
# Token: people, POS: NOUN, Dep: nmod, Head: �
# Token: �, POS: PROPN, Dep: ccomp, Head: amplify
# Token: s, POS: PART, Dep: dobj, Head: amplify
# Token: ability, POS: NOUN, Dep: dobj, Head: amplify
# Token: to, POS: PART, Dep: aux, Head: help
# Token: help, POS: VERB, Dep: acl, Head: ability
# Token: others, POS: NOUN, Dep: dobj, Head: help
# Token: ., POS: PUNCT, Dep: punct, Head: creates
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: For more information, press only:
#
# Microsoft Media Relations, WE Communications, (425) 638-7777, rrt@we-worldwide.com
#
# Note to editors: For more information, news and perspectives from Microsoft, please visit the Microsoft News Center at http://news.microsoft.com.
#
# Token: For, POS: ADP, Dep: prep, Head: press
# Token: more, POS: ADJ, Dep: amod, Head: information
# Token: information, POS: NOUN, Dep: pobj, Head: For
# Token: ,, POS: PUNCT, Dep: punct, Head: press
# Token: press, POS: NOUN, Dep: ROOT, Head: press
# Token: only, POS: ADV, Dep: advmod, Head: press
# Token: :, POS: PUNCT, Dep: punct, Head: press
# Token:
#
# , POS: SPACE, Dep: dep, Head: :
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Relations
# Token: Media, POS: PROPN, Dep: compound, Head: Relations
# Token: Relations, POS: PROPN, Dep: appos, Head: press
# Token: ,, POS: PUNCT, Dep: punct, Head: Relations
# Token: WE, POS: PROPN, Dep: compound, Head: Communications
# Token: Communications, POS: PROPN, Dep: conj, Head: Relations
# Token: ,, POS: PUNCT, Dep: punct, Head: Communications
# Token: (, POS: PUNCT, Dep: punct, Head: Communications
# Token: 425, POS: NUM, Dep: appos, Head: Communications
# Token: ), POS: PUNCT, Dep: punct, Head: 425
# Token: 638, POS: NUM, Dep: npadvmod, Head: press
# Token: -, POS: SYM, Dep: punct, Head: 7777
# Token: 7777, POS: NUM, Dep: prep, Head: 638
# Token: ,, POS: PUNCT, Dep: punct, Head: Note
# Token: rrt@we-worldwide.com, POS: PROPN, Dep: compound, Head: Note
# Token:
#
# , POS: SPACE, Dep: dep, Head: rrt@we-worldwide.com
# Token: Note, POS: VERB, Dep: ccomp, Head: visit
# Token: to, POS: ADP, Dep: prep, Head: Note
# Token: editors, POS: NOUN, Dep: pobj, Head: to
# Token: :, POS: PUNCT, Dep: punct, Head: visit
# Token: For, POS: ADP, Dep: prep, Head: visit
# Token: more, POS: ADJ, Dep: amod, Head: information
# Token: information, POS: NOUN, Dep: pobj, Head: For
# Token: ,, POS: PUNCT, Dep: punct, Head: information
# Token: news, POS: NOUN, Dep: conj, Head: information
# Token: and, POS: CCONJ, Dep: cc, Head: news
# Token: perspectives, POS: NOUN, Dep: conj, Head: news
# Token: from, POS: ADP, Dep: prep, Head: information
# Token: Microsoft, POS: PROPN, Dep: pobj, Head: from
# Token: ,, POS: PUNCT, Dep: punct, Head: visit
# Token: please, POS: INTJ, Dep: intj, Head: visit
# Token: visit, POS: VERB, Dep: ccomp, Head: press
# Token: the, POS: DET, Dep: det, Head: Center
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Center
# Token: News, POS: PROPN, Dep: compound, Head: Center
# Token: Center, POS: PROPN, Dep: dobj, Head: visit
# Token: at, POS: ADP, Dep: prep, Head: visit
# Token: http://news.microsoft.com, POS: X, Dep: pobj, Head: at
# Token: ., POS: PUNCT, Dep: punct, Head: press
#
# Sentence: Web links, telephone numbers and titles were correct at time of publication but may have changed.
#
# Token: Web, POS: NOUN, Dep: compound, Head: links
# Token: links, POS: NOUN, Dep: nsubj, Head: were
# Token: ,, POS: PUNCT, Dep: punct, Head: links
# Token: telephone, POS: NOUN, Dep: compound, Head: numbers
# Token: numbers, POS: NOUN, Dep: conj, Head: links
# Token: and, POS: CCONJ, Dep: cc, Head: numbers
# Token: titles, POS: NOUN, Dep: conj, Head: numbers
# Token: were, POS: AUX, Dep: ROOT, Head: were
# Token: correct, POS: ADJ, Dep: acomp, Head: were
# Token: at, POS: ADP, Dep: prep, Head: were
# Token: time, POS: NOUN, Dep: pobj, Head: at
# Token: of, POS: ADP, Dep: prep, Head: time
# Token: publication, POS: NOUN, Dep: pobj, Head: of
# Token: but, POS: CCONJ, Dep: cc, Head: were
# Token: may, POS: AUX, Dep: aux, Head: changed
# Token: have, POS: AUX, Dep: aux, Head: changed
# Token: changed, POS: VERB, Dep: conj, Head: were
# Token: ., POS: PUNCT, Dep: punct, Head: were
#
# Sentence: For additional assistance, journalists and analysts may contact Microsoft�s Rapid Response Team or other appropriate contacts listed at https://news.microsoft.com/microsoft-public-relations-contacts.
#
#
#
# Token: For, POS: ADP, Dep: prep, Head: contact
# Token: additional, POS: ADJ, Dep: amod, Head: assistance
# Token: assistance, POS: NOUN, Dep: pobj, Head: For
# Token: ,, POS: PUNCT, Dep: punct, Head: contact
# Token: journalists, POS: NOUN, Dep: nsubj, Head: contact
# Token: and, POS: CCONJ, Dep: cc, Head: journalists
# Token: analysts, POS: NOUN, Dep: conj, Head: journalists
# Token: may, POS: AUX, Dep: aux, Head: contact
# Token: contact, POS: VERB, Dep: ROOT, Head: contact
# Token: Microsoft, POS: PROPN, Dep: compound, Head: Team
# Token: �, POS: NOUN, Dep: poss, Head: Team
# Token: s, POS: PART, Dep: case, Head: �
# Token: Rapid, POS: PROPN, Dep: compound, Head: Response
# Token: Response, POS: PROPN, Dep: compound, Head: Team
# Token: Team, POS: PROPN, Dep: dobj, Head: contact
# Token: or, POS: CCONJ, Dep: cc, Head: Team
# Token: other, POS: ADJ, Dep: amod, Head: contacts
# Token: appropriate, POS: ADJ, Dep: amod, Head: contacts
# Token: contacts, POS: NOUN, Dep: conj, Head: Team
# Token: listed, POS: VERB, Dep: acl, Head: contacts
# Token: at, POS: ADP, Dep: prep, Head: listed
# Token: https://news.microsoft.com/microsoft-public-relations-contacts, POS: NOUN, Dep: pobj, Head: at
# Token: ., POS: PUNCT, Dep: punct, Head: contact
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Trademark reference: Nuance and the Nuance logo are registered trademarks or trademarks of Nuance Communications, Inc. or its affiliates in the United States and/or other countries.
#
# Token: Trademark, POS: PROPN, Dep: compound, Head: reference
# Token: reference, POS: NOUN, Dep: ROOT, Head: reference
# Token: :, POS: PUNCT, Dep: punct, Head: reference
# Token: Nuance, POS: PROPN, Dep: nsubj, Head: are
# Token: and, POS: CCONJ, Dep: cc, Head: Nuance
# Token: the, POS: DET, Dep: det, Head: logo
# Token: Nuance, POS: PROPN, Dep: compound, Head: logo
# Token: logo, POS: NOUN, Dep: conj, Head: Nuance
# Token: are, POS: AUX, Dep: acl, Head: reference
# Token: registered, POS: VERB, Dep: amod, Head: trademarks
# Token: trademarks, POS: NOUN, Dep: attr, Head: are
# Token: or, POS: CCONJ, Dep: cc, Head: trademarks
# Token: trademarks, POS: NOUN, Dep: conj, Head: trademarks
# Token: of, POS: ADP, Dep: prep, Head: trademarks
# Token: Nuance, POS: PROPN, Dep: nmod, Head: Communications
# Token: Communications, POS: PROPN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: Communications
# Token: Inc., POS: PROPN, Dep: conj, Head: Communications
# Token: or, POS: CCONJ, Dep: cc, Head: Inc.
# Token: its, POS: PRON, Dep: poss, Head: affiliates
# Token: affiliates, POS: NOUN, Dep: conj, Head: Inc.
# Token: in, POS: ADP, Dep: prep, Head: affiliates
# Token: the, POS: DET, Dep: det, Head: States
# Token: United, POS: PROPN, Dep: compound, Head: States
# Token: States, POS: PROPN, Dep: pobj, Head: in
# Token: and/or, POS: CCONJ, Dep: cc, Head: States
# Token: other, POS: ADJ, Dep: amod, Head: countries
# Token: countries, POS: NOUN, Dep: conj, Head: States
# Token: ., POS: PUNCT, Dep: punct, Head: are
#
# Sentence: All other trademarks
#
# Token: All, POS: DET, Dep: det, Head: trademarks
# Token: other, POS: ADJ, Dep: amod, Head: trademarks
# Token: trademarks, POS: NOUN, Dep: ROOT, Head: trademarks
#
# Named Entities in ai_forecast1:
# Entity: Pune, India, Label: GPE
# Entity: Sept. 13, 2022, Label: DATE
# Entity: GLOBE NEWSWIRE, Label: ORG
# Entity: AI, Label: ORG
# Entity: USD 387.45 billion, Label: MONEY
# Entity: 2022, Label: DATE
# Entity: USD 1394.30 billion, Label: MONEY
# Entity: 2029, Label: DATE
# Entity: 20.1%, Label: PERCENT
# Entity: AI, Label: ORG
# Entity: the next several years, Label: DATE
# Entity: 2022-2029, Label: DATE
# Entity: USD 328.34 billion, Label: MONEY
# Entity: 2021, Label: DATE
# Entity: BFSI, Label: ORG
# Entity: Request a Sample Copy of the Research Report, Label: WORK_OF_ART
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: GPE
# Entity: April 12, Label: DATE
# Entity: 2021, Label: DATE
# Entity: Microsoft News Center
#
# Share on Facebook, Label: ORG
# Entity: LinkedIn, Label: GPE
# Entity: Twitter, Label: PERSON
# Entity: AI, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: GPE
# Entity: REDMOND, Label: GPE
# Entity: Wash., Label: GPE
# Entity: BURLINGTON, Label: GPE
# Entity: Mass., Label: GPE
# Entity: April 12, Label: DATE
# Entity: 2021, Label: DATE
# Entity: Microsoft Corp, Label: ORG
# Entity: Nuance Communications, Inc., Label: ORG
# Entity: today, Label: DATE
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: GPE
# Entity: 56.00, Label: MONEY
# Entity: 23%, Label: PERCENT
# Entity: Nuance, Label: GPE
# Entity: Friday, April 9, Label: DATE
# Entity: $19.7 billion, Label: MONEY
# Entity: Nuance, Label: WORK_OF_ART
# Entity: AI, Label: ORG
# Entity: decades, Label: DATE
# Entity: AI, Label: ORG
# Entity: Mark Benjamin, Label: PERSON
# Entity: Nuance, Label: GPE
# Entity: Scott Guthrie, Label: PERSON
# Entity: Cloud & AI, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: this calendar year, Label: DATE
# Entity: Microsoft, Label: ORG
# Entity: the Microsoft Cloud for, Label: ORG
# Entity: Healthcare, Label: ORG
# Entity: 2020, Label: DATE
# Entity: Today, Label: DATE
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: WORK_OF_ART
# Entity: AI, Label: ORG
# Entity: the Dragon Ambient eXperience, Label: ORG
# Entity: Dragon Medical One, Label: ORG
# Entity: PowerScribe, Label: ORG
# Entity: Microsoft Azure, Label: ORG
# Entity: Electronic Health Records, Label: ORG
# Entity: more than 55%, Label: PERCENT
# Entity: 75%, Label: PERCENT
# Entity: U.S., Label: GPE
# Entity: 77%, Label: PERCENT
# Entity: U.S., Label: GPE
# Entity: Healthcare, Label: ORG
# Entity: 37%, Label: PERCENT
# Entity: year-over-year, Label: DATE
# Entity: Nuance, Label: GPE
# Entity: s fiscal year 2020, Label: DATE
# Entity: September 2020, Label: DATE
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: GPE
# Entity: 2019, Label: DATE
# Entity: the Microsoft Cloud for, Label: ORG
# Entity: Healthcare, Label: ORG
# Entity: Nuance, Label: WORK_OF_ART
# Entity: Nuance, Label: WORK_OF_ART
# Entity: Microsoft, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: TAM, Label: ORG
# Entity: TAM, Label: ORG
# Entity: nearly $500 billion, Label: MONEY
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: WORK_OF_ART
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG
# Entity: Satya Nadella, Label: PERSON
# Entity: Microsoft, Label: ORG
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG
# Entity: Microsoft Cloud, Label: ORG
# Entity: Healthcare, Label: ORG
# Entity: Nuance, Label: GPE
# Entity: Nuance, Label: GPE
# Entity: AI, Label: ORG
# Entity: Interactive Voice Response, Label: ORG
# Entity: IVR, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: Azure, Teams, Label: WORK_OF_ART
# Entity: Dynamics 365, Label: ORG
# Entity: the past three years, Label: DATE
# Entity: Nuance, Label: GPE
# Entity: AI, Label: ORG
# Entity: Mark Benjamin, Label: PERSON
# Entity: Nuance, Label: GPE
# Entity: Microsoft, Label: ORG
# Entity: the Boards of Directors, Label: ORG
# Entity: Nuance, Label: GPE
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: WORK_OF_ART
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: WORK_OF_ART
# Entity: Microsoft, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: less than 1 percent, Label: PERCENT
# Entity: fiscal year 2022, Label: DATE
# Entity: fiscal year 2023, Label: DATE
# Entity: Nadella, Label: PERSON
# Entity: Benjamin, Label: PERSON
# Entity: Guthrie, Label: PERSON
# Entity: Microsoft, Label: ORG
# Entity: Amy Hood, Label: PERSON
# Entity: April 12, 2021, Label: DATE
# Entity: 8 a.m. Pacific Time/11 a.m., Label: TIME
# Entity: Eastern Time, Label: PERSON
# Entity: 201, Label: CARDINAL
# Entity: 689-8023, Label: CARDINAL
# Entity: U.S., Label: GPE
# Entity: 877, Label: CARDINAL
# Entity: 407, Label: CARDINAL
# Entity: Goldman Sachs & Co., Label: ORG
# Entity: LLC, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: Simpson Thacher & Bartlett LLP, Label: ORG
# Entity: Nuance, Label: GPE
# Entity: Paul, Label: PERSON
# Entity: Weiss, Label: ORG
# Entity: Rifkind, Wharton & Garrison LLP, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: About Nuance Communications, Label: ORG
# Entity: Nuance Communications, Label: ORG
# Entity: AI, Label: ORG
# Entity: 77 percent, Label: PERCENT
# Entity: U.S., Label: GPE
# Entity: 85 percent, Label: PERCENT
# Entity: Fortune 100, Label: LAW
# Entity: Nuance, Label: GPE
# Entity: Microsoft Media Relations, Label: ORG
# Entity: 425, Label: CARDINAL
# Entity: 638, Label: CARDINAL
# Entity: Microsoft, Label: ORG
# Entity: the Microsoft News Center, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: Nuance, Label: WORK_OF_ART
# Entity: Nuance Communications, Label: ORG
# Entity: the United States, Label: GPE

# %%
# Perform tokenization, POS tagging, sentence parsing (dep) and named entity recognition (NER) on ai_forecast2
print("\n\nAnalysis of ai_forecast2.txt")
for sent in doc_ai_forecast2.sents:
    print(f"\nSentence: {sent.text}\n")

    for token in sent:
        print(f"Token: {token.text}, POS: {token.pos_}, Dep: {token.dep_}, Head: {token.head.text}")

# Named entities in ai_forecast2
print("\nNamed Entities in ai_forecast2:")
for ent in doc_ai_forecast2.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Analysis of ai_forecast2.txt
#
# Sentence: The global artificial intelligence market size was $93.5 billion in 2021.
#
# Token: The, POS: DET, Dep: det, Head: size
# Token: global, POS: ADJ, Dep: amod, Head: size
# Token: artificial, POS: ADJ, Dep: amod, Head: size
# Token: intelligence, POS: NOUN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: compound, Head: size
# Token: size, POS: NOUN, Dep: nsubj, Head: was
# Token: was, POS: AUX, Dep: ROOT, Head: was
# Token: $, POS: SYM, Dep: quantmod, Head: billion
# Token: 93.5, POS: NUM, Dep: compound, Head: billion
# Token: billion, POS: NUM, Dep: attr, Head: was
# Token: in, POS: ADP, Dep: prep, Head: was
# Token: 2021, POS: NUM, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: was
#
# Sentence: And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.
#
# Token: And, POS: CCONJ, Dep: cc, Head: projected
# Token: according, POS: VERB, Dep: prep, Head: projected
# Token: to, POS: ADP, Dep: prep, Head: according
# Token: Grand, POS: PROPN, Dep: compound, Head: Inc.
# Token: View, POS: PROPN, Dep: compound, Head: Inc.
# Token: Research, POS: PROPN, Dep: nmod, Head: Inc.
# Token: ,, POS: PUNCT, Dep: punct, Head: Inc.
# Token: Inc., POS: PROPN, Dep: pobj, Head: to
# Token: ,, POS: PUNCT, Dep: punct, Head: projected
# Token: it, POS: PRON, Dep: nsubjpass, Head: projected
# Token: is, POS: AUX, Dep: auxpass, Head: projected
# Token: projected, POS: VERB, Dep: ROOT, Head: projected
# Token: to, POS: PART, Dep: aux, Head: expand
# Token: expand, POS: VERB, Dep: xcomp, Head: projected
# Token: at, POS: ADP, Dep: prep, Head: expand
# Token: a, POS: DET, Dep: det, Head: rate
# Token: compound, POS: ADJ, Dep: nmod, Head: rate
# Token: annual, POS: ADJ, Dep: amod, Head: rate
# Token: growth, POS: NOUN, Dep: compound, Head: rate
# Token: rate, POS: NOUN, Dep: pobj, Head: at
# Token: (, POS: PUNCT, Dep: punct, Head: rate
# Token: CAGR, POS: PROPN, Dep: appos, Head: rate
# Token: ), POS: PUNCT, Dep: punct, Head: rate
# Token: of, POS: ADP, Dep: prep, Head: rate
# Token: 38.1, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: pobj, Head: of
# Token: from, POS: ADP, Dep: prep, Head: rate
# Token: 2022, POS: NUM, Dep: pobj, Head: from
# Token: to, POS: ADP, Dep: prep, Head: rate
# Token: 2030, POS: NUM, Dep: pobj, Head: to
# Token: ., POS: PUNCT, Dep: punct, Head: projected
#
# Sentence: The market is driven by the increasing number of connected devices, growing demand for personalized services, and a need for real-time solutions.
#
# Token: The, POS: DET, Dep: det, Head: market
# Token: market, POS: NOUN, Dep: nsubjpass, Head: driven
# Token: is, POS: AUX, Dep: auxpass, Head: driven
# Token: driven, POS: VERB, Dep: ROOT, Head: driven
# Token: by, POS: ADP, Dep: agent, Head: driven
# Token: the, POS: DET, Dep: det, Head: number
# Token: increasing, POS: VERB, Dep: amod, Head: number
# Token: number, POS: NOUN, Dep: pobj, Head: by
# Token: of, POS: ADP, Dep: prep, Head: number
# Token: connected, POS: ADJ, Dep: amod, Head: devices
# Token: devices, POS: NOUN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: devices
# Token: growing, POS: VERB, Dep: amod, Head: demand
# Token: demand, POS: NOUN, Dep: conj, Head: number
# Token: for, POS: ADP, Dep: prep, Head: demand
# Token: personalized, POS: ADJ, Dep: amod, Head: services
# Token: services, POS: NOUN, Dep: pobj, Head: for
# Token: ,, POS: PUNCT, Dep: punct, Head: demand
# Token: and, POS: CCONJ, Dep: cc, Head: demand
# Token: a, POS: DET, Dep: det, Head: need
# Token: need, POS: NOUN, Dep: conj, Head: demand
# Token: for, POS: ADP, Dep: prep, Head: need
# Token: real, POS: ADJ, Dep: amod, Head: time
# Token: -, POS: PUNCT, Dep: punct, Head: time
# Token: time, POS: NOUN, Dep: compound, Head: solutions
# Token: solutions, POS: NOUN, Dep: pobj, Head: for
# Token: ., POS: PUNCT, Dep: punct, Head: driven
#
# Sentence: Additionally, advancements in cloud computing technology, along with developments in deep learning algorithms, have increased the adoption rate of AI.
#
#
#
# Token: Additionally, POS: ADV, Dep: advmod, Head: increased
# Token: ,, POS: PUNCT, Dep: punct, Head: increased
# Token: advancements, POS: NOUN, Dep: nsubj, Head: increased
# Token: in, POS: ADP, Dep: prep, Head: advancements
# Token: cloud, POS: ADJ, Dep: compound, Head: technology
# Token: computing, POS: NOUN, Dep: compound, Head: technology
# Token: technology, POS: NOUN, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: increased
# Token: along, POS: ADP, Dep: prep, Head: increased
# Token: with, POS: ADP, Dep: prep, Head: along
# Token: developments, POS: NOUN, Dep: pobj, Head: with
# Token: in, POS: ADP, Dep: prep, Head: developments
# Token: deep, POS: ADJ, Dep: amod, Head: learning
# Token: learning, POS: NOUN, Dep: compound, Head: algorithms
# Token: algorithms, POS: NOUN, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: increased
# Token: have, POS: AUX, Dep: aux, Head: increased
# Token: increased, POS: VERB, Dep: ROOT, Head: increased
# Token: the, POS: DET, Dep: det, Head: rate
# Token: adoption, POS: NOUN, Dep: compound, Head: rate
# Token: rate, POS: NOUN, Dep: dobj, Head: increased
# Token: of, POS: ADP, Dep: prep, Head: rate
# Token: AI, POS: PROPN, Dep: pobj, Head: of
# Token: ., POS: PUNCT, Dep: punct, Head: increased
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Artificial intelligence growth can be attributed to its widespread application across diverse sectors, including healthcare, retail, and finance.
#
# Token: Artificial, POS: ADJ, Dep: amod, Head: growth
# Token: intelligence, POS: NOUN, Dep: compound, Head: growth
# Token: growth, POS: NOUN, Dep: nsubjpass, Head: attributed
# Token: can, POS: AUX, Dep: aux, Head: attributed
# Token: be, POS: AUX, Dep: auxpass, Head: attributed
# Token: attributed, POS: VERB, Dep: ROOT, Head: attributed
# Token: to, POS: ADP, Dep: prep, Head: attributed
# Token: its, POS: PRON, Dep: poss, Head: application
# Token: widespread, POS: ADJ, Dep: amod, Head: application
# Token: application, POS: NOUN, Dep: pobj, Head: to
# Token: across, POS: ADP, Dep: prep, Head: attributed
# Token: diverse, POS: ADJ, Dep: amod, Head: sectors
# Token: sectors, POS: NOUN, Dep: pobj, Head: across
# Token: ,, POS: PUNCT, Dep: punct, Head: sectors
# Token: including, POS: VERB, Dep: prep, Head: sectors
# Token: healthcare, POS: NOUN, Dep: pobj, Head: including
# Token: ,, POS: PUNCT, Dep: punct, Head: healthcare
# Token: retail, POS: NOUN, Dep: conj, Head: healthcare
# Token: ,, POS: PUNCT, Dep: punct, Head: retail
# Token: and, POS: CCONJ, Dep: cc, Head: retail
# Token: finance, POS: NOUN, Dep: conj, Head: retail
# Token: ., POS: PUNCT, Dep: punct, Head: attributed
#
# Sentence: However, some challenges must be addressed before it can reach mainstream adoption.
#
# Token: However, POS: ADV, Dep: advmod, Head: addressed
# Token: ,, POS: PUNCT, Dep: punct, Head: addressed
# Token: some, POS: DET, Dep: det, Head: challenges
# Token: challenges, POS: NOUN, Dep: nsubjpass, Head: addressed
# Token: must, POS: AUX, Dep: aux, Head: addressed
# Token: be, POS: AUX, Dep: auxpass, Head: addressed
# Token: addressed, POS: VERB, Dep: ROOT, Head: addressed
# Token: before, POS: SCONJ, Dep: mark, Head: reach
# Token: it, POS: PRON, Dep: nsubj, Head: reach
# Token: can, POS: AUX, Dep: aux, Head: reach
# Token: reach, POS: VERB, Dep: advcl, Head: addressed
# Token: mainstream, POS: NOUN, Dep: compound, Head: adoption
# Token: adoption, POS: NOUN, Dep: dobj, Head: reach
# Token: ., POS: PUNCT, Dep: punct, Head: addressed
#
# Sentence: These hurdles include high infrastructure costs associated with implementing AI systems and a lack of awareness about these technologies among businesses that could benefit from them.
#
#
#
# Token: These, POS: DET, Dep: det, Head: hurdles
# Token: hurdles, POS: NOUN, Dep: nsubj, Head: include
# Token: include, POS: VERB, Dep: ROOT, Head: include
# Token: high, POS: ADJ, Dep: amod, Head: costs
# Token: infrastructure, POS: NOUN, Dep: compound, Head: costs
# Token: costs, POS: NOUN, Dep: dobj, Head: include
# Token: associated, POS: VERB, Dep: acl, Head: costs
# Token: with, POS: ADP, Dep: prep, Head: associated
# Token: implementing, POS: VERB, Dep: pcomp, Head: with
# Token: AI, POS: PROPN, Dep: compound, Head: systems
# Token: systems, POS: NOUN, Dep: dobj, Head: implementing
# Token: and, POS: CCONJ, Dep: cc, Head: costs
# Token: a, POS: DET, Dep: det, Head: lack
# Token: lack, POS: NOUN, Dep: conj, Head: costs
# Token: of, POS: ADP, Dep: prep, Head: lack
# Token: awareness, POS: NOUN, Dep: pobj, Head: of
# Token: about, POS: ADP, Dep: prep, Head: awareness
# Token: these, POS: DET, Dep: det, Head: technologies
# Token: technologies, POS: NOUN, Dep: pobj, Head: about
# Token: among, POS: ADP, Dep: prep, Head: technologies
# Token: businesses, POS: NOUN, Dep: pobj, Head: among
# Token: that, POS: PRON, Dep: nsubj, Head: benefit
# Token: could, POS: AUX, Dep: aux, Head: benefit
# Token: benefit, POS: VERB, Dep: relcl, Head: businesses
# Token: from, POS: ADP, Dep: prep, Head: benefit
# Token: them, POS: PRON, Dep: pobj, Head: from
# Token: ., POS: PUNCT, Dep: punct, Head: include
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: The artificial intelligence market is segmented based on product type, application, and region.
#
# Token: The, POS: DET, Dep: det, Head: market
# Token: artificial, POS: ADJ, Dep: amod, Head: market
# Token: intelligence, POS: NOUN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: nsubjpass, Head: segmented
# Token: is, POS: AUX, Dep: auxpass, Head: segmented
# Token: segmented, POS: VERB, Dep: ROOT, Head: segmented
# Token: based, POS: VERB, Dep: prep, Head: segmented
# Token: on, POS: ADP, Dep: prep, Head: based
# Token: product, POS: NOUN, Dep: compound, Head: type
# Token: type, POS: NOUN, Dep: pobj, Head: on
# Token: ,, POS: PUNCT, Dep: punct, Head: type
# Token: application, POS: NOUN, Dep: conj, Head: type
# Token: ,, POS: PUNCT, Dep: punct, Head: application
# Token: and, POS: CCONJ, Dep: cc, Head: application
# Token: region, POS: NOUN, Dep: conj, Head: application
# Token: ., POS: PUNCT, Dep: punct, Head: segmented
#
# Sentence: Based on product type, the market has been subdivided into service robots and software.
#
# Token: Based, POS: VERB, Dep: prep, Head: subdivided
# Token: on, POS: ADP, Dep: prep, Head: Based
# Token: product, POS: NOUN, Dep: compound, Head: type
# Token: type, POS: NOUN, Dep: pobj, Head: on
# Token: ,, POS: PUNCT, Dep: punct, Head: subdivided
# Token: the, POS: DET, Dep: det, Head: market
# Token: market, POS: NOUN, Dep: nsubjpass, Head: subdivided
# Token: has, POS: AUX, Dep: aux, Head: subdivided
# Token: been, POS: AUX, Dep: auxpass, Head: subdivided
# Token: subdivided, POS: VERB, Dep: ROOT, Head: subdivided
# Token: into, POS: ADP, Dep: prep, Head: subdivided
# Token: service, POS: NOUN, Dep: compound, Head: robots
# Token: robots, POS: NOUN, Dep: pobj, Head: into
# Token: and, POS: CCONJ, Dep: cc, Head: robots
# Token: software, POS: NOUN, Dep: conj, Head: robots
# Token: ., POS: PUNCT, Dep: punct, Head: subdivided
#
# Sentence: The services portion accounted for around 66% share in 2016.
#
# Token: The, POS: DET, Dep: det, Head: portion
# Token: services, POS: NOUN, Dep: compound, Head: portion
# Token: portion, POS: NOUN, Dep: nsubj, Head: accounted
# Token: accounted, POS: VERB, Dep: ROOT, Head: accounted
# Token: for, POS: ADP, Dep: prep, Head: accounted
# Token: around, POS: ADP, Dep: quantmod, Head: 66
# Token: 66, POS: NUM, Dep: nummod, Head: %
# Token: %, POS: NOUN, Dep: compound, Head: share
# Token: share, POS: NOUN, Dep: pobj, Head: for
# Token: in, POS: ADP, Dep: prep, Head: accounted
# Token: 2016, POS: NUM, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: accounted
#
# Sentence: Based on application, AI has segmented into healthcare and life sciences; manufacturing and logistics; energy and utilities; banking, financial services, and insurance (BFSI); process manufacturing industries; retail and eCommerce; and agriculture and forestry sectors (agribusinesses).
#
#
#
# Token: Based, POS: VERB, Dep: prep, Head: segmented
# Token: on, POS: ADP, Dep: prep, Head: Based
# Token: application, POS: NOUN, Dep: pobj, Head: on
# Token: ,, POS: PUNCT, Dep: punct, Head: segmented
# Token: AI, POS: PROPN, Dep: nsubj, Head: segmented
# Token: has, POS: AUX, Dep: aux, Head: segmented
# Token: segmented, POS: VERB, Dep: ROOT, Head: segmented
# Token: into, POS: ADP, Dep: prep, Head: segmented
# Token: healthcare, POS: NOUN, Dep: nmod, Head: sciences
# Token: and, POS: CCONJ, Dep: cc, Head: healthcare
# Token: life, POS: NOUN, Dep: conj, Head: healthcare
# Token: sciences, POS: NOUN, Dep: pobj, Head: into
# Token: ;, POS: PUNCT, Dep: punct, Head: sciences
# Token: manufacturing, POS: NOUN, Dep: conj, Head: sciences
# Token: and, POS: CCONJ, Dep: cc, Head: manufacturing
# Token: logistics, POS: NOUN, Dep: conj, Head: manufacturing
# Token: ;, POS: PUNCT, Dep: punct, Head: manufacturing
# Token: energy, POS: NOUN, Dep: conj, Head: manufacturing
# Token: and, POS: CCONJ, Dep: cc, Head: energy
# Token: utilities, POS: NOUN, Dep: conj, Head: energy
# Token: ;, POS: PUNCT, Dep: punct, Head: manufacturing
# Token: banking, POS: NOUN, Dep: conj, Head: manufacturing
# Token: ,, POS: PUNCT, Dep: punct, Head: banking
# Token: financial, POS: ADJ, Dep: amod, Head: services
# Token: services, POS: NOUN, Dep: conj, Head: banking
# Token: ,, POS: PUNCT, Dep: punct, Head: services
# Token: and, POS: CCONJ, Dep: cc, Head: services
# Token: insurance, POS: NOUN, Dep: conj, Head: services
# Token: (, POS: PUNCT, Dep: punct, Head: insurance
# Token: BFSI, POS: PROPN, Dep: appos, Head: insurance
# Token: ), POS: PUNCT, Dep: punct, Head: insurance
# Token: ;, POS: PUNCT, Dep: punct, Head: segmented
# Token: process, POS: NOUN, Dep: compound, Head: manufacturing
# Token: manufacturing, POS: NOUN, Dep: compound, Head: industries
# Token: industries, POS: NOUN, Dep: dobj, Head: segmented
# Token: ;, POS: PUNCT, Dep: punct, Head: industries
# Token: retail, POS: PROPN, Dep: conj, Head: industries
# Token: and, POS: CCONJ, Dep: cc, Head: retail
# Token: eCommerce, POS: PROPN, Dep: conj, Head: retail
# Token: ;, POS: PUNCT, Dep: punct, Head: retail
# Token: and, POS: CCONJ, Dep: cc, Head: retail
# Token: agriculture, POS: NOUN, Dep: conj, Head: retail
# Token: and, POS: CCONJ, Dep: cc, Head: agriculture
# Token: forestry, POS: NOUN, Dep: conj, Head: agriculture
# Token: sectors, POS: NOUN, Dep: conj, Head: agriculture
# Token: (, POS: PUNCT, Dep: punct, Head: retail
# Token: agribusinesses, POS: NOUN, Dep: appos, Head: retail
# Token: ), POS: PUNCT, Dep: punct, Head: retail
# Token: ., POS: PUNCT, Dep: punct, Head: segmented
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: The healthcare sector holds significant potential for AI across various applications.
#
# Token: The, POS: DET, Dep: det, Head: sector
# Token: healthcare, POS: NOUN, Dep: compound, Head: sector
# Token: sector, POS: NOUN, Dep: nsubj, Head: holds
# Token: holds, POS: VERB, Dep: ROOT, Head: holds
# Token: significant, POS: ADJ, Dep: amod, Head: potential
# Token: potential, POS: NOUN, Dep: dobj, Head: holds
# Token: for, POS: ADP, Dep: prep, Head: potential
# Token: AI, POS: PROPN, Dep: pobj, Head: for
# Token: across, POS: ADP, Dep: prep, Head: holds
# Token: various, POS: ADJ, Dep: amod, Head: applications
# Token: applications, POS: NOUN, Dep: pobj, Head: across
# Token: ., POS: PUNCT, Dep: punct, Head: holds
#
# Sentence: This includes medical imaging analysis, molecular biology research, and drug discovery.
#
# Token: This, POS: PRON, Dep: nsubj, Head: includes
# Token: includes, POS: VERB, Dep: ROOT, Head: includes
# Token: medical, POS: ADJ, Dep: amod, Head: imaging
# Token: imaging, POS: NOUN, Dep: compound, Head: analysis
# Token: analysis, POS: NOUN, Dep: dobj, Head: includes
# Token: ,, POS: PUNCT, Dep: punct, Head: analysis
# Token: molecular, POS: ADJ, Dep: amod, Head: research
# Token: biology, POS: NOUN, Dep: compound, Head: research
# Token: research, POS: NOUN, Dep: conj, Head: analysis
# Token: ,, POS: PUNCT, Dep: punct, Head: research
# Token: and, POS: CCONJ, Dep: cc, Head: research
# Token: drug, POS: NOUN, Dep: compound, Head: discovery
# Token: discovery, POS: NOUN, Dep: conj, Head: research
# Token: ., POS: PUNCT, Dep: punct, Head: includes
#
# Sentence: Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).
#
# Token: Additionally, POS: ADV, Dep: advmod, Head: are
# Token: ,, POS: PUNCT, Dep: punct, Head: are
# Token: there, POS: PRON, Dep: expl, Head: are
# Token: are, POS: VERB, Dep: ROOT, Head: are
# Token: developments, POS: NOUN, Dep: attr, Head: are
# Token: in, POS: ADP, Dep: prep, Head: developments
# Token: drug, POS: NOUN, Dep: compound, Head: optimization
# Token: optimization, POS: NOUN, Dep: pobj, Head: in
# Token: through, POS: ADP, Dep: prep, Head: developments
# Token: predictive, POS: ADJ, Dep: amod, Head: analytics
# Token: analytics, POS: NOUN, Dep: compound, Head: tools
# Token: tools, POS: NOUN, Dep: pobj, Head: through
# Token: provided, POS: VERB, Dep: acl, Head: tools
# Token: by, POS: ADP, Dep: agent, Head: provided
# Token: leading, POS: VERB, Dep: amod, Head: players
# Token: players, POS: NOUN, Dep: pobj, Head: by
# Token: ,, POS: PUNCT, Dep: punct, Head: players
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: players
# Token: NVIDIA, POS: PROPN, Dep: compound, Head: Corporation
# Token: Corporation, POS: PROPN, Dep: pobj, Head: as
# Token: (, POS: PUNCT, Dep: punct, Head: Corporation
# Token: NVDA, POS: PROPN, Dep: appos, Head: Corporation
# Token: ), POS: PUNCT, Dep: punct, Head: Corporation
# Token: ,, POS: PUNCT, Dep: punct, Head: Corporation
# Token: Intel, POS: PROPN, Dep: compound, Head: Corporation
# Token: Corporation, POS: PROPN, Dep: conj, Head: Corporation
# Token: (, POS: PUNCT, Dep: punct, Head: Corporation
# Token: INTC, POS: PROPN, Dep: appos, Head: Corporation
# Token: ), POS: PUNCT, Dep: punct, Head: Corporation
# Token: ,, POS: PUNCT, Dep: punct, Head: Corporation
# Token: Alphabet, POS: PROPN, Dep: compound, Head: Inc.
# Token: Inc., POS: PROPN, Dep: conj, Head: Corporation
# Token: (, POS: PUNCT, Dep: punct, Head: Inc.
# Token: GOOGL, POS: PROPN, Dep: npadvmod, Head: Inc.
# Token: ), POS: PUNCT, Dep: punct, Head: Inc.
# Token: ,, POS: PUNCT, Dep: punct, Head: Corporation
# Token: and, POS: CCONJ, Dep: cc, Head: Corporation
# Token: Amazon, POS: PROPN, Dep: compound, Head: Inc.
# Token: Web, POS: PROPN, Dep: compound, Head: Inc.
# Token: Services, POS: PROPN, Dep: compound, Head: Inc.
# Token: Inc., POS: PROPN, Dep: conj, Head: Corporation
# Token: (, POS: PUNCT, Dep: punct, Head: Inc.
# Token: AMZN, POS: PROPN, Dep: appos, Head: Inc.
# Token: ), POS: PUNCT, Dep: punct, Head: Inc.
# Token: ., POS: PUNCT, Dep: punct, Head: are
#
# Sentence: This is primarily due to their high adoption rate among researchers worldwide coupled with increasing demand from patients willing to pay extra if provided better care due to side effects associated with traditional treatment methods.
#
#
# Token: This, POS: PRON, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: primarily, POS: ADV, Dep: advmod, Head: is
# Token: due, POS: ADJ, Dep: acomp, Head: is
# Token: to, POS: ADP, Dep: pcomp, Head: due
# Token: their, POS: PRON, Dep: poss, Head: rate
# Token: high, POS: ADJ, Dep: amod, Head: rate
# Token: adoption, POS: NOUN, Dep: compound, Head: rate
# Token: rate, POS: NOUN, Dep: pobj, Head: to
# Token: among, POS: ADP, Dep: prep, Head: rate
# Token: researchers, POS: NOUN, Dep: pobj, Head: among
# Token: worldwide, POS: ADV, Dep: advmod, Head: researchers
# Token: coupled, POS: VERB, Dep: acl, Head: rate
# Token: with, POS: ADP, Dep: prep, Head: coupled
# Token: increasing, POS: VERB, Dep: amod, Head: demand
# Token: demand, POS: NOUN, Dep: pobj, Head: with
# Token: from, POS: ADP, Dep: prep, Head: demand
# Token: patients, POS: NOUN, Dep: pobj, Head: from
# Token: willing, POS: ADJ, Dep: amod, Head: patients
# Token: to, POS: PART, Dep: aux, Head: pay
# Token: pay, POS: VERB, Dep: xcomp, Head: willing
# Token: extra, POS: ADJ, Dep: dobj, Head: pay
# Token: if, POS: SCONJ, Dep: mark, Head: provided
# Token: provided, POS: VERB, Dep: advcl, Head: is
# Token: better, POS: ADJ, Dep: amod, Head: care
# Token: care, POS: NOUN, Dep: dobj, Head: provided
# Token: due, POS: ADP, Dep: prep, Head: provided
# Token: to, POS: ADP, Dep: pcomp, Head: due
# Token: side, POS: NOUN, Dep: compound, Head: effects
# Token: effects, POS: NOUN, Dep: pobj, Head: due
# Token: associated, POS: VERB, Dep: acl, Head: effects
# Token: with, POS: ADP, Dep: prep, Head: associated
# Token: traditional, POS: ADJ, Dep: amod, Head: methods
# Token: treatment, POS: NOUN, Dep: compound, Head: methods
# Token: methods, POS: NOUN, Dep: pobj, Head: with
# Token: ., POS: PUNCT, Dep: punct, Head: is
# Token:
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.
#
# Token: Artificial, POS: PROPN, Dep: compound, Head: Market
# Token: Intelligence, POS: PROPN, Dep: compound, Head: Market
# Token: Market, POS: PROPN, Dep: nsubjpass, Head: segmented
# Token: by, POS: ADP, Dep: prep, Head: Market
# Token: Component, POS: PROPN, Dep: compound, Head: Analysis
# Token: Analysis, POS: PROPN, Dep: compound, Head: AI
# Token:
#
# , POS: SPACE, Dep: dep, Head: Analysis
# Token: AI, POS: PROPN, Dep: compound, Head: analysis
# Token: market, POS: NOUN, Dep: compound, Head: analysis
# Token: analysis, POS: NOUN, Dep: pobj, Head: by
# Token: can, POS: AUX, Dep: aux, Head: segmented
# Token: be, POS: AUX, Dep: auxpass, Head: segmented
# Token: segmented, POS: VERB, Dep: ROOT, Head: segmented
# Token: into, POS: ADP, Dep: prep, Head: segmented
# Token: hardware, POS: NOUN, Dep: nmod, Head: components
# Token: ,, POS: PUNCT, Dep: punct, Head: hardware
# Token: software, POS: NOUN, Dep: conj, Head: hardware
# Token: ,, POS: PUNCT, Dep: punct, Head: software
# Token: and, POS: CCONJ, Dep: cc, Head: software
# Token: service, POS: NOUN, Dep: compound, Head: components
# Token: components, POS: NOUN, Dep: pobj, Head: into
# Token: ., POS: PUNCT, Dep: punct, Head: segmented
#
# Sentence: The hardware segment is expected to grow at the highest CAGR during the forecast period.
#
# Token: The, POS: DET, Dep: det, Head: segment
# Token: hardware, POS: NOUN, Dep: compound, Head: segment
# Token: segment, POS: NOUN, Dep: nsubjpass, Head: expected
# Token: is, POS: AUX, Dep: auxpass, Head: expected
# Token: expected, POS: VERB, Dep: ROOT, Head: expected
# Token: to, POS: PART, Dep: aux, Head: grow
# Token: grow, POS: VERB, Dep: xcomp, Head: expected
# Token: at, POS: ADP, Dep: prep, Head: grow
# Token: the, POS: DET, Dep: det, Head: CAGR
# Token: highest, POS: ADJ, Dep: amod, Head: CAGR
# Token: CAGR, POS: PROPN, Dep: pobj, Head: at
# Token: during, POS: ADP, Dep: prep, Head: grow
# Token: the, POS: DET, Dep: det, Head: period
# Token: forecast, POS: NOUN, Dep: compound, Head: period
# Token: period, POS: NOUN, Dep: pobj, Head: during
# Token: ., POS: PUNCT, Dep: punct, Head: expected
#
# Sentence: The need for AI services is projected to rise as smart solutions such as virtual assistants and personalized online experiences become more widely used.
#
# Token: The, POS: DET, Dep: det, Head: need
# Token: need, POS: NOUN, Dep: nsubjpass, Head: projected
# Token: for, POS: ADP, Dep: prep, Head: need
# Token: AI, POS: PROPN, Dep: compound, Head: services
# Token: services, POS: NOUN, Dep: pobj, Head: for
# Token: is, POS: AUX, Dep: auxpass, Head: projected
# Token: projected, POS: VERB, Dep: ROOT, Head: projected
# Token: to, POS: PART, Dep: aux, Head: rise
# Token: rise, POS: VERB, Dep: xcomp, Head: projected
# Token: as, POS: ADP, Dep: prep, Head: rise
# Token: smart, POS: ADJ, Dep: amod, Head: solutions
# Token: solutions, POS: NOUN, Dep: pobj, Head: as
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: solutions
# Token: virtual, POS: ADJ, Dep: amod, Head: assistants
# Token: assistants, POS: NOUN, Dep: pobj, Head: as
# Token: and, POS: CCONJ, Dep: cc, Head: projected
# Token: personalized, POS: VERB, Dep: conj, Head: projected
# Token: online, POS: ADJ, Dep: amod, Head: experiences
# Token: experiences, POS: NOUN, Dep: dobj, Head: personalized
# Token: become, POS: VERB, Dep: conj, Head: projected
# Token: more, POS: ADV, Dep: advmod, Head: widely
# Token: widely, POS: ADV, Dep: advmod, Head: used
# Token: used, POS: ADJ, Dep: acomp, Head: become
# Token: ., POS: PUNCT, Dep: punct, Head: projected
#
# Sentence: These services use AI capabilities to improve business operations, such as creating automated and accurate sales projections based on client interactions and sales data.
#
#
# Token: These, POS: DET, Dep: det, Head: services
# Token: services, POS: NOUN, Dep: nsubj, Head: use
# Token: use, POS: VERB, Dep: ROOT, Head: use
# Token: AI, POS: PROPN, Dep: compound, Head: capabilities
# Token: capabilities, POS: NOUN, Dep: dobj, Head: use
# Token: to, POS: PART, Dep: aux, Head: improve
# Token: improve, POS: VERB, Dep: xcomp, Head: use
# Token: business, POS: NOUN, Dep: compound, Head: operations
# Token: operations, POS: NOUN, Dep: dobj, Head: improve
# Token: ,, POS: PUNCT, Dep: punct, Head: operations
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: operations
# Token: creating, POS: VERB, Dep: pcomp, Head: as
# Token: automated, POS: VERB, Dep: amod, Head: sales
# Token: and, POS: CCONJ, Dep: cc, Head: automated
# Token: accurate, POS: ADJ, Dep: conj, Head: automated
# Token: sales, POS: NOUN, Dep: compound, Head: projections
# Token: projections, POS: NOUN, Dep: dobj, Head: creating
# Token: based, POS: VERB, Dep: acl, Head: projections
# Token: on, POS: ADP, Dep: prep, Head: based
# Token: client, POS: NOUN, Dep: compound, Head: interactions
# Token: interactions, POS: NOUN, Dep: pobj, Head: on
# Token: and, POS: CCONJ, Dep: cc, Head: interactions
# Token: sales, POS: NOUN, Dep: compound, Head: data
# Token: data, POS: NOUN, Dep: conj, Head: interactions
# Token: ., POS: PUNCT, Dep: punct, Head: use
# Token:
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Artificial Intelligence Market by Technology
#
#
#
# Token: Artificial, POS: PROPN, Dep: compound, Head: Market
# Token: Intelligence, POS: PROPN, Dep: compound, Head: Market
# Token: Market, POS: PROPN, Dep: ROOT, Head: Market
# Token: by, POS: ADP, Dep: prep, Head: Market
# Token: Technology, POS: PROPN, Dep: pobj, Head: by
# Token:
#
# , POS: SPACE, Dep: dep, Head: Technology
#
# Sentence: There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.
#
# Token: There, POS: PRON, Dep: expl, Head: are
# Token: are, POS: VERB, Dep: ccomp, Head: be
# Token: many, POS: ADJ, Dep: amod, Head: types
# Token: different, POS: ADJ, Dep: amod, Head: types
# Token: types, POS: NOUN, Dep: attr, Head: are
# Token: of, POS: ADP, Dep: prep, Head: types
# Token: artificial, POS: ADJ, Dep: amod, Head: intelligence
# Token: intelligence, POS: NOUN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: be
# Token: so, POS: SCONJ, Dep: mark, Head: be
# Token: it, POS: PRON, Dep: nsubj, Head: be
# Token: can, POS: AUX, Dep: aux, Head: be
# Token: be, POS: AUX, Dep: ROOT, Head: be
# Token: difficult, POS: ADJ, Dep: acomp, Head: be
# Token: to, POS: PART, Dep: aux, Head: understand
# Token: understand, POS: VERB, Dep: xcomp, Head: be
# Token: the, POS: DET, Dep: det, Head: market
# Token: market, POS: NOUN, Dep: dobj, Head: understand
# Token: without, POS: ADP, Dep: prep, Head: understand
# Token: an, POS: DET, Dep: det, Head: overview
# Token: overview, POS: NOUN, Dep: pobj, Head: without
# Token: of, POS: ADP, Dep: prep, Head: overview
# Token: the, POS: DET, Dep: det, Head: technology
# Token: technology, POS: NOUN, Dep: pobj, Head: of
# Token: ., POS: PUNCT, Dep: punct, Head: be
#
# Sentence: The AI market is further segmented by technology.
#
# Token: The, POS: DET, Dep: det, Head: market
# Token: AI, POS: PROPN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: nsubjpass, Head: segmented
# Token: is, POS: AUX, Dep: auxpass, Head: segmented
# Token: further, POS: ADV, Dep: advmod, Head: segmented
# Token: segmented, POS: VERB, Dep: ROOT, Head: segmented
# Token: by, POS: ADP, Dep: agent, Head: segmented
# Token: technology, POS: NOUN, Dep: pobj, Head: by
# Token: ., POS: PUNCT, Dep: punct, Head: segmented
#
# Sentence: Natural language processing (NLP), machine learning, context-aware computing, computer vision, and virtual agents are some major technologies used in the AI market.
#
#
#
# Token: Natural, POS: ADJ, Dep: amod, Head: language
# Token: language, POS: NOUN, Dep: compound, Head: processing
# Token: processing, POS: NOUN, Dep: nsubj, Head: are
# Token: (, POS: PUNCT, Dep: punct, Head: processing
# Token: NLP, POS: PROPN, Dep: appos, Head: processing
# Token: ), POS: PUNCT, Dep: punct, Head: processing
# Token: ,, POS: PUNCT, Dep: punct, Head: processing
# Token: machine, POS: NOUN, Dep: compound, Head: learning
# Token: learning, POS: NOUN, Dep: conj, Head: processing
# Token: ,, POS: PUNCT, Dep: punct, Head: learning
# Token: context, POS: NOUN, Dep: npadvmod, Head: aware
# Token: -, POS: PUNCT, Dep: punct, Head: aware
# Token: aware, POS: ADJ, Dep: amod, Head: computing
# Token: computing, POS: NOUN, Dep: conj, Head: learning
# Token: ,, POS: PUNCT, Dep: punct, Head: computing
# Token: computer, POS: NOUN, Dep: compound, Head: vision
# Token: vision, POS: NOUN, Dep: conj, Head: computing
# Token: ,, POS: PUNCT, Dep: punct, Head: vision
# Token: and, POS: CCONJ, Dep: cc, Head: vision
# Token: virtual, POS: ADJ, Dep: amod, Head: agents
# Token: agents, POS: NOUN, Dep: conj, Head: vision
# Token: are, POS: AUX, Dep: ROOT, Head: are
# Token: some, POS: DET, Dep: det, Head: technologies
# Token: major, POS: ADJ, Dep: amod, Head: technologies
# Token: technologies, POS: NOUN, Dep: attr, Head: are
# Token: used, POS: VERB, Dep: acl, Head: technologies
# Token: in, POS: ADP, Dep: prep, Head: used
# Token: the, POS: DET, Dep: det, Head: market
# Token: AI, POS: PROPN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: are
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: NLP enables a system to understand human language through various methods like speech recognition and natural language understanding.
#
# Token: NLP, POS: PROPN, Dep: nsubj, Head: enables
# Token: enables, POS: VERB, Dep: ROOT, Head: enables
# Token: a, POS: DET, Dep: det, Head: system
# Token: system, POS: NOUN, Dep: dobj, Head: enables
# Token: to, POS: PART, Dep: aux, Head: understand
# Token: understand, POS: VERB, Dep: relcl, Head: system
# Token: human, POS: ADJ, Dep: amod, Head: language
# Token: language, POS: NOUN, Dep: dobj, Head: understand
# Token: through, POS: ADP, Dep: prep, Head: understand
# Token: various, POS: ADJ, Dep: amod, Head: methods
# Token: methods, POS: NOUN, Dep: pobj, Head: through
# Token: like, POS: ADP, Dep: prep, Head: methods
# Token: speech, POS: NOUN, Dep: compound, Head: recognition
# Token: recognition, POS: NOUN, Dep: pobj, Head: like
# Token: and, POS: CCONJ, Dep: cc, Head: recognition
# Token: natural, POS: ADJ, Dep: amod, Head: language
# Token: language, POS: NOUN, Dep: compound, Head: understanding
# Token: understanding, POS: NOUN, Dep: conj, Head: recognition
# Token: ., POS: PUNCT, Dep: punct, Head: enables
#
# Sentence: Machine learning refers to the process of developing an algorithm that can automatically learn from its experience without being explicitly programmed.
#
# Token: Machine, POS: NOUN, Dep: compound, Head: learning
# Token: learning, POS: NOUN, Dep: nsubj, Head: refers
# Token: refers, POS: VERB, Dep: ROOT, Head: refers
# Token: to, POS: ADP, Dep: prep, Head: refers
# Token: the, POS: DET, Dep: det, Head: process
# Token: process, POS: NOUN, Dep: pobj, Head: to
# Token: of, POS: ADP, Dep: prep, Head: process
# Token: developing, POS: VERB, Dep: pcomp, Head: of
# Token: an, POS: DET, Dep: det, Head: algorithm
# Token: algorithm, POS: PROPN, Dep: dobj, Head: developing
# Token: that, POS: PRON, Dep: nsubj, Head: learn
# Token: can, POS: AUX, Dep: aux, Head: learn
# Token: automatically, POS: ADV, Dep: advmod, Head: learn
# Token: learn, POS: VERB, Dep: relcl, Head: algorithm
# Token: from, POS: ADP, Dep: prep, Head: learn
# Token: its, POS: PRON, Dep: poss, Head: experience
# Token: experience, POS: NOUN, Dep: pobj, Head: from
# Token: without, POS: ADP, Dep: prep, Head: learn
# Token: being, POS: AUX, Dep: auxpass, Head: programmed
# Token: explicitly, POS: ADV, Dep: advmod, Head: programmed
# Token: programmed, POS: VERB, Dep: pcomp, Head: without
# Token: ., POS: PUNCT, Dep: punct, Head: refers
#
# Sentence: Context-aware computing refers to systems that adapt their behavior according to their surroundings or environment, such as GPS location services on smartphones or self-driving cars.
#
#
#
# Token: Context, POS: NOUN, Dep: npadvmod, Head: aware
# Token: -, POS: PUNCT, Dep: punct, Head: aware
# Token: aware, POS: ADJ, Dep: amod, Head: computing
# Token: computing, POS: NOUN, Dep: nsubj, Head: refers
# Token: refers, POS: VERB, Dep: ROOT, Head: refers
# Token: to, POS: ADP, Dep: prep, Head: refers
# Token: systems, POS: NOUN, Dep: pobj, Head: to
# Token: that, POS: PRON, Dep: nsubj, Head: adapt
# Token: adapt, POS: VERB, Dep: relcl, Head: systems
# Token: their, POS: PRON, Dep: poss, Head: behavior
# Token: behavior, POS: NOUN, Dep: dobj, Head: adapt
# Token: according, POS: VERB, Dep: prep, Head: adapt
# Token: to, POS: ADP, Dep: prep, Head: according
# Token: their, POS: PRON, Dep: poss, Head: surroundings
# Token: surroundings, POS: NOUN, Dep: pobj, Head: to
# Token: or, POS: CCONJ, Dep: cc, Head: surroundings
# Token: environment, POS: NOUN, Dep: conj, Head: surroundings
# Token: ,, POS: PUNCT, Dep: punct, Head: surroundings
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: surroundings
# Token: GPS, POS: PROPN, Dep: compound, Head: services
# Token: location, POS: NOUN, Dep: compound, Head: services
# Token: services, POS: NOUN, Dep: pobj, Head: as
# Token: on, POS: ADP, Dep: prep, Head: services
# Token: smartphones, POS: NOUN, Dep: pobj, Head: on
# Token: or, POS: CCONJ, Dep: cc, Head: smartphones
# Token: self, POS: NOUN, Dep: npadvmod, Head: driving
# Token: -, POS: PUNCT, Dep: punct, Head: driving
# Token: driving, POS: VERB, Dep: amod, Head: cars
# Token: cars, POS: NOUN, Dep: conj, Head: smartphones
# Token: ., POS: PUNCT, Dep: punct, Head: refers
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Computer vision refers to techniques used to process images for perception tasks, such as facial recognition, which plays a role in self-driving cars that can detect pedestrians at night in low visibility conditions.
#
#
# Token: Computer, POS: NOUN, Dep: compound, Head: vision
# Token: vision, POS: NOUN, Dep: nsubj, Head: refers
# Token: refers, POS: VERB, Dep: ROOT, Head: refers
# Token: to, POS: ADP, Dep: prep, Head: refers
# Token: techniques, POS: NOUN, Dep: pobj, Head: to
# Token: used, POS: VERB, Dep: acl, Head: techniques
# Token: to, POS: PART, Dep: aux, Head: process
# Token: process, POS: VERB, Dep: xcomp, Head: used
# Token: images, POS: NOUN, Dep: dobj, Head: process
# Token: for, POS: ADP, Dep: prep, Head: images
# Token: perception, POS: NOUN, Dep: compound, Head: tasks
# Token: tasks, POS: NOUN, Dep: pobj, Head: for
# Token: ,, POS: PUNCT, Dep: punct, Head: tasks
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: tasks
# Token: facial, POS: ADJ, Dep: amod, Head: recognition
# Token: recognition, POS: NOUN, Dep: pobj, Head: as
# Token: ,, POS: PUNCT, Dep: punct, Head: recognition
# Token: which, POS: PRON, Dep: nsubj, Head: plays
# Token: plays, POS: VERB, Dep: relcl, Head: recognition
# Token: a, POS: DET, Dep: det, Head: role
# Token: role, POS: NOUN, Dep: dobj, Head: plays
# Token: in, POS: ADP, Dep: prep, Head: role
# Token: self, POS: NOUN, Dep: npadvmod, Head: driving
# Token: -, POS: PUNCT, Dep: punct, Head: driving
# Token: driving, POS: VERB, Dep: amod, Head: cars
# Token: cars, POS: NOUN, Dep: pobj, Head: in
# Token: that, POS: PRON, Dep: nsubj, Head: detect
# Token: can, POS: AUX, Dep: aux, Head: detect
# Token: detect, POS: VERB, Dep: relcl, Head: role
# Token: pedestrians, POS: NOUN, Dep: dobj, Head: detect
# Token: at, POS: ADP, Dep: prep, Head: detect
# Token: night, POS: NOUN, Dep: pobj, Head: at
# Token: in, POS: ADP, Dep: prep, Head: detect
# Token: low, POS: ADJ, Dep: amod, Head: visibility
# Token: visibility, POS: NOUN, Dep: compound, Head: conditions
# Token: conditions, POS: NOUN, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: refers
# Token:
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: Artificial Intelligence Market by End-User Industry
#
#
#
# Token: Artificial, POS: PROPN, Dep: compound, Head: Market
# Token: Intelligence, POS: PROPN, Dep: compound, Head: Market
# Token: Market, POS: PROPN, Dep: ROOT, Head: Market
# Token: by, POS: ADP, Dep: prep, Head: Market
# Token: End, POS: PROPN, Dep: compound, Head: Industry
# Token: -, POS: PUNCT, Dep: punct, Head: Industry
# Token: User, POS: PROPN, Dep: compound, Head: Industry
# Token: Industry, POS: PROPN, Dep: pobj, Head: by
# Token:
#
# , POS: SPACE, Dep: dep, Head: Industry
#
# Sentence: The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
#
#
# Token: The, POS: DET, Dep: det, Head: market
# Token: AI, POS: PROPN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: nsubjpass, Head: segmented
# Token: is, POS: AUX, Dep: auxpass, Head: segmented
# Token: segmented, POS: VERB, Dep: ROOT, Head: segmented
# Token: by, POS: ADP, Dep: agent, Head: segmented
# Token: end, POS: NOUN, Dep: compound, Head: user
# Token: -, POS: PUNCT, Dep: punct, Head: user
# Token: user, POS: NOUN, Dep: compound, Head: industry
# Token: industry, POS: NOUN, Dep: pobj, Head: by
# Token: into, POS: ADP, Dep: prep, Head: segmented
# Token: retail, POS: ADJ, Dep: pobj, Head: into
# Token: ,, POS: PUNCT, Dep: punct, Head: retail
# Token: healthcare, POS: NOUN, Dep: conj, Head: retail
# Token: and, POS: CCONJ, Dep: cc, Head: healthcare
# Token: life, POS: NOUN, Dep: conj, Head: healthcare
# Token: sciences, POS: PROPN, Dep: conj, Head: healthcare
# Token: ,, POS: PUNCT, Dep: punct, Head: sciences
# Token: automotive, POS: ADJ, Dep: conj, Head: sciences
# Token: and, POS: CCONJ, Dep: cc, Head: automotive
# Token: transportation, POS: NOUN, Dep: conj, Head: automotive
# Token: ,, POS: PUNCT, Dep: punct, Head: automotive
# Token: BFSI, POS: PROPN, Dep: conj, Head: automotive
# Token: ,, POS: PUNCT, Dep: punct, Head: healthcare
# Token: consumer, POS: NOUN, Dep: compound, Head: goods
# Token: goods, POS: NOUN, Dep: conj, Head: healthcare
# Token: and, POS: CCONJ, Dep: cc, Head: goods
# Token: retail, POS: NOUN, Dep: conj, Head: goods
# Token: ,, POS: PUNCT, Dep: punct, Head: retail
# Token: manufacturing, POS: NOUN, Dep: conj, Head: retail
# Token: ,, POS: PUNCT, Dep: punct, Head: manufacturing
# Token: media, POS: NOUN, Dep: conj, Head: manufacturing
# Token: and, POS: CCONJ, Dep: cc, Head: media
# Token: entertainment, POS: NOUN, Dep: conj, Head: media
# Token: ,, POS: PUNCT, Dep: punct, Head: entertainment
# Token: agriculture, POS: NOUN, Dep: conj, Head: entertainment
# Token: and, POS: CCONJ, Dep: cc, Head: agriculture
# Token: food, POS: NOUN, Dep: conj, Head: agriculture
# Token: ,, POS: PUNCT, Dep: punct, Head: food
# Token: and, POS: CCONJ, Dep: cc, Head: food
# Token: energy, POS: NOUN, Dep: conj, Head: food
# Token: and, POS: CCONJ, Dep: cc, Head: energy
# Token: utilities, POS: NOUN, Dep: conj, Head: energy
# Token: ., POS: PUNCT, Dep: punct, Head: segmented
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: The retail sector accounted for one of the largest shares of the AI market in 2020.
#
# Token: The, POS: DET, Dep: det, Head: sector
# Token: retail, POS: ADJ, Dep: amod, Head: sector
# Token: sector, POS: NOUN, Dep: nsubj, Head: accounted
# Token: accounted, POS: VERB, Dep: ROOT, Head: accounted
# Token: for, POS: ADP, Dep: prep, Head: accounted
# Token: one, POS: NUM, Dep: pobj, Head: for
# Token: of, POS: ADP, Dep: prep, Head: one
# Token: the, POS: DET, Dep: det, Head: shares
# Token: largest, POS: ADJ, Dep: amod, Head: shares
# Token: shares, POS: NOUN, Dep: pobj, Head: of
# Token: of, POS: ADP, Dep: prep, Head: shares
# Token: the, POS: DET, Dep: det, Head: market
# Token: AI, POS: PROPN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: pobj, Head: of
# Token: in, POS: ADP, Dep: prep, Head: accounted
# Token: 2020, POS: NUM, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: accounted
#
# Sentence: This can be attributed to the rise in smartphone usage across the globe, as well as an increase in the use of smart devices.
#
# Token: This, POS: PRON, Dep: nsubjpass, Head: attributed
# Token: can, POS: AUX, Dep: aux, Head: attributed
# Token: be, POS: AUX, Dep: auxpass, Head: attributed
# Token: attributed, POS: VERB, Dep: ROOT, Head: attributed
# Token: to, POS: ADP, Dep: prep, Head: attributed
# Token: the, POS: DET, Dep: det, Head: rise
# Token: rise, POS: NOUN, Dep: pobj, Head: to
# Token: in, POS: ADP, Dep: prep, Head: rise
# Token: smartphone, POS: ADJ, Dep: compound, Head: usage
# Token: usage, POS: NOUN, Dep: pobj, Head: in
# Token: across, POS: ADP, Dep: prep, Head: rise
# Token: the, POS: DET, Dep: det, Head: globe
# Token: globe, POS: NOUN, Dep: pobj, Head: across
# Token: ,, POS: PUNCT, Dep: punct, Head: rise
# Token: as, POS: ADV, Dep: advmod, Head: as
# Token: well, POS: ADV, Dep: advmod, Head: as
# Token: as, POS: ADP, Dep: cc, Head: rise
# Token: an, POS: DET, Dep: det, Head: increase
# Token: increase, POS: NOUN, Dep: conj, Head: rise
# Token: in, POS: ADP, Dep: prep, Head: increase
# Token: the, POS: DET, Dep: det, Head: use
# Token: use, POS: NOUN, Dep: pobj, Head: in
# Token: of, POS: ADP, Dep: prep, Head: use
# Token: smart, POS: ADJ, Dep: amod, Head: devices
# Token: devices, POS: NOUN, Dep: pobj, Head: of
# Token: ., POS: PUNCT, Dep: punct, Head: attributed
#
# Sentence: Smartphones have also increased the demand for mobile commerce platforms, such as the customized CoverGirl app.
#
# Token: Smartphones, POS: NOUN, Dep: nsubj, Head: increased
# Token: have, POS: AUX, Dep: aux, Head: increased
# Token: also, POS: ADV, Dep: advmod, Head: increased
# Token: increased, POS: VERB, Dep: ROOT, Head: increased
# Token: the, POS: DET, Dep: det, Head: demand
# Token: demand, POS: NOUN, Dep: dobj, Head: increased
# Token: for, POS: ADP, Dep: prep, Head: demand
# Token: mobile, POS: ADJ, Dep: compound, Head: commerce
# Token: commerce, POS: NOUN, Dep: compound, Head: platforms
# Token: platforms, POS: NOUN, Dep: pobj, Head: for
# Token: ,, POS: PUNCT, Dep: punct, Head: platforms
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: platforms
# Token: the, POS: DET, Dep: det, Head: app
# Token: customized, POS: VERB, Dep: amod, Head: app
# Token: CoverGirl, POS: PROPN, Dep: compound, Head: app
# Token: app, POS: NOUN, Dep: pobj, Head: as
# Token: ., POS: PUNCT, Dep: punct, Head: increased
#
# Sentence: The app employs predictive analytics software and applies real-time data to deliver personalized experiences to customers based on their preferences.
#
#
#
# Token: The, POS: DET, Dep: det, Head: app
# Token: app, POS: NOUN, Dep: nsubj, Head: employs
# Token: employs, POS: VERB, Dep: ROOT, Head: employs
# Token: predictive, POS: ADJ, Dep: amod, Head: analytics
# Token: analytics, POS: NOUN, Dep: compound, Head: software
# Token: software, POS: NOUN, Dep: dobj, Head: employs
# Token: and, POS: CCONJ, Dep: cc, Head: employs
# Token: applies, POS: VERB, Dep: conj, Head: employs
# Token: real, POS: ADJ, Dep: amod, Head: time
# Token: -, POS: PUNCT, Dep: punct, Head: time
# Token: time, POS: NOUN, Dep: compound, Head: data
# Token: data, POS: NOUN, Dep: dobj, Head: applies
# Token: to, POS: PART, Dep: aux, Head: deliver
# Token: deliver, POS: VERB, Dep: xcomp, Head: applies
# Token: personalized, POS: VERB, Dep: amod, Head: experiences
# Token: experiences, POS: NOUN, Dep: dobj, Head: deliver
# Token: to, POS: ADP, Dep: prep, Head: deliver
# Token: customers, POS: NOUN, Dep: pobj, Head: to
# Token: based, POS: VERB, Dep: prep, Head: deliver
# Token: on, POS: ADP, Dep: prep, Head: based
# Token: their, POS: PRON, Dep: poss, Head: preferences
# Token: preferences, POS: NOUN, Dep: pobj, Head: on
# Token: ., POS: PUNCT, Dep: punct, Head: employs
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: The automotive industry also accounted for a sizable share of the global artificial intelligence market.
#
# Token: The, POS: DET, Dep: det, Head: industry
# Token: automotive, POS: ADJ, Dep: amod, Head: industry
# Token: industry, POS: NOUN, Dep: nsubj, Head: accounted
# Token: also, POS: ADV, Dep: advmod, Head: accounted
# Token: accounted, POS: VERB, Dep: ROOT, Head: accounted
# Token: for, POS: ADP, Dep: prep, Head: accounted
# Token: a, POS: DET, Dep: det, Head: share
# Token: sizable, POS: ADJ, Dep: amod, Head: share
# Token: share, POS: NOUN, Dep: pobj, Head: for
# Token: of, POS: ADP, Dep: prep, Head: share
# Token: the, POS: DET, Dep: det, Head: market
# Token: global, POS: ADJ, Dep: amod, Head: market
# Token: artificial, POS: ADJ, Dep: amod, Head: market
# Token: intelligence, POS: NOUN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: pobj, Head: of
# Token: ., POS: PUNCT, Dep: punct, Head: accounted
#
# Sentence: This can be attributed to the increased adoption of self-driving vehicles globally.
#
# Token: This, POS: PRON, Dep: nsubjpass, Head: attributed
# Token: can, POS: AUX, Dep: aux, Head: attributed
# Token: be, POS: AUX, Dep: auxpass, Head: attributed
# Token: attributed, POS: VERB, Dep: ROOT, Head: attributed
# Token: to, POS: ADP, Dep: prep, Head: attributed
# Token: the, POS: DET, Dep: det, Head: adoption
# Token: increased, POS: VERB, Dep: amod, Head: adoption
# Token: adoption, POS: NOUN, Dep: pobj, Head: to
# Token: of, POS: ADP, Dep: prep, Head: adoption
# Token: self, POS: NOUN, Dep: npadvmod, Head: driving
# Token: -, POS: PUNCT, Dep: punct, Head: driving
# Token: driving, POS: VERB, Dep: amod, Head: vehicles
# Token: vehicles, POS: NOUN, Dep: pobj, Head: of
# Token: globally, POS: ADV, Dep: advmod, Head: attributed
# Token: ., POS: PUNCT, Dep: punct, Head: attributed
#
# Sentence: This has also led to more adoption of intelligent transportation systems, such as electronic toll collection, ramp meters, red light cameras, traffic signal coordination, transit signal priority, and traveler information systems.
#
#
#
# Token: This, POS: PRON, Dep: nsubj, Head: led
# Token: has, POS: AUX, Dep: aux, Head: led
# Token: also, POS: ADV, Dep: advmod, Head: led
# Token: led, POS: VERB, Dep: ROOT, Head: led
# Token: to, POS: ADP, Dep: prep, Head: led
# Token: more, POS: ADJ, Dep: amod, Head: adoption
# Token: adoption, POS: NOUN, Dep: pobj, Head: to
# Token: of, POS: ADP, Dep: prep, Head: adoption
# Token: intelligent, POS: ADJ, Dep: amod, Head: systems
# Token: transportation, POS: NOUN, Dep: compound, Head: systems
# Token: systems, POS: NOUN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: systems
# Token: such, POS: ADJ, Dep: amod, Head: as
# Token: as, POS: ADP, Dep: prep, Head: systems
# Token: electronic, POS: ADJ, Dep: amod, Head: collection
# Token: toll, POS: NOUN, Dep: compound, Head: collection
# Token: collection, POS: NOUN, Dep: pobj, Head: as
# Token: ,, POS: PUNCT, Dep: punct, Head: collection
# Token: ramp, POS: NOUN, Dep: compound, Head: meters
# Token: meters, POS: NOUN, Dep: conj, Head: collection
# Token: ,, POS: PUNCT, Dep: punct, Head: meters
# Token: red, POS: ADJ, Dep: amod, Head: light
# Token: light, POS: NOUN, Dep: compound, Head: cameras
# Token: cameras, POS: NOUN, Dep: conj, Head: meters
# Token: ,, POS: PUNCT, Dep: punct, Head: cameras
# Token: traffic, POS: NOUN, Dep: compound, Head: signal
# Token: signal, POS: NOUN, Dep: compound, Head: coordination
# Token: coordination, POS: NOUN, Dep: conj, Head: cameras
# Token: ,, POS: PUNCT, Dep: punct, Head: coordination
# Token: transit, POS: NOUN, Dep: compound, Head: priority
# Token: signal, POS: NOUN, Dep: compound, Head: priority
# Token: priority, POS: NOUN, Dep: conj, Head: coordination
# Token: ,, POS: PUNCT, Dep: punct, Head: priority
# Token: and, POS: CCONJ, Dep: cc, Head: priority
# Token: traveler, POS: NOUN, Dep: compound, Head: information
# Token: information, POS: NOUN, Dep: compound, Head: systems
# Token: systems, POS: NOUN, Dep: conj, Head: priority
# Token: ., POS: PUNCT, Dep: punct, Head: led
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# ...
#
# Sentence: As such, North America is expected to hold the largest share of the AI market during the coming years.
#
# Token: As, POS: ADP, Dep: prep, Head: expected
# Token: such, POS: ADJ, Dep: amod, Head: As
# Token: ,, POS: PUNCT, Dep: punct, Head: expected
# Token: North, POS: PROPN, Dep: compound, Head: America
# Token: America, POS: PROPN, Dep: nsubjpass, Head: expected
# Token: is, POS: AUX, Dep: auxpass, Head: expected
# Token: expected, POS: VERB, Dep: ROOT, Head: expected
# Token: to, POS: PART, Dep: aux, Head: hold
# Token: hold, POS: VERB, Dep: xcomp, Head: expected
# Token: the, POS: DET, Dep: det, Head: share
# Token: largest, POS: ADJ, Dep: amod, Head: share
# Token: share, POS: NOUN, Dep: dobj, Head: hold
# Token: of, POS: ADP, Dep: prep, Head: share
# Token: the, POS: DET, Dep: det, Head: market
# Token: AI, POS: PROPN, Dep: compound, Head: market
# Token: market, POS: NOUN, Dep: pobj, Head: of
# Token: during, POS: ADP, Dep: prep, Head: hold
# Token: the, POS: DET, Dep: det, Head: years
# Token: coming, POS: VERB, Dep: amod, Head: years
# Token: years, POS: NOUN, Dep: pobj, Head: during
# Token: ., POS: PUNCT, Dep: punct, Head: expected
#
# Sentence: North America is home to several technology companies and has a strong network of research and development centers in this domain.
#
# Token: North, POS: PROPN, Dep: compound, Head: America
# Token: America, POS: PROPN, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: home, POS: NOUN, Dep: advmod, Head: is
# Token: to, POS: ADP, Dep: prep, Head: home
# Token: several, POS: ADJ, Dep: amod, Head: companies
# Token: technology, POS: NOUN, Dep: compound, Head: companies
# Token: companies, POS: NOUN, Dep: pobj, Head: to
# Token: and, POS: CCONJ, Dep: cc, Head: is
# Token: has, POS: VERB, Dep: conj, Head: is
# Token: a, POS: DET, Dep: det, Head: network
# Token: strong, POS: ADJ, Dep: amod, Head: network
# Token: network, POS: NOUN, Dep: dobj, Head: has
# Token: of, POS: ADP, Dep: prep, Head: network
# Token: research, POS: NOUN, Dep: nmod, Head: centers
# Token: and, POS: CCONJ, Dep: cc, Head: research
# Token: development, POS: NOUN, Dep: conj, Head: research
# Token: centers, POS: NOUN, Dep: pobj, Head: of
# Token: in, POS: ADP, Dep: prep, Head: network
# Token: this, POS: DET, Dep: det, Head: domain
# Token: domain, POS: NOUN, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: is
#
# Sentence: The U.S., Canada, and Mexico are major markets for AI-based services and technologies.
#
# Token: The, POS: DET, Dep: det, Head: U.S.
# Token: U.S., POS: PROPN, Dep: nsubj, Head: are
# Token: ,, POS: PUNCT, Dep: punct, Head: U.S.
# Token: Canada, POS: PROPN, Dep: appos, Head: U.S.
# Token: ,, POS: PUNCT, Dep: punct, Head: U.S.
# Token: and, POS: CCONJ, Dep: cc, Head: U.S.
# Token: Mexico, POS: PROPN, Dep: conj, Head: U.S.
# Token: are, POS: AUX, Dep: ROOT, Head: are
# Token: major, POS: ADJ, Dep: amod, Head: markets
# Token: markets, POS: NOUN, Dep: attr, Head: are
# Token: for, POS: ADP, Dep: prep, Head: markets
# Token: AI, POS: PROPN, Dep: npadvmod, Head: based
# Token: -, POS: PUNCT, Dep: punct, Head: based
# Token: based, POS: VERB, Dep: amod, Head: services
# Token: services, POS: NOUN, Dep: pobj, Head: for
# Token: and, POS: CCONJ, Dep: cc, Head: services
# Token: technologies, POS: NOUN, Dep: conj, Head: services
# Token: ., POS: PUNCT, Dep: punct, Head: are
#
# Sentence: Furthermore, North America accounts for many global venture capital investments in AI startups, which indicates its growing adoption rate by businesses worldwide.
#
#
#
# Token: Furthermore, POS: ADV, Dep: advmod, Head: accounts
# Token: ,, POS: PUNCT, Dep: punct, Head: accounts
# Token: North, POS: PROPN, Dep: compound, Head: America
# Token: America, POS: PROPN, Dep: nsubj, Head: accounts
# Token: accounts, POS: VERB, Dep: ROOT, Head: accounts
# Token: for, POS: ADP, Dep: prep, Head: accounts
# Token: many, POS: ADJ, Dep: amod, Head: investments
# Token: global, POS: ADJ, Dep: amod, Head: capital
# Token: venture, POS: NOUN, Dep: compound, Head: capital
# Token: capital, POS: NOUN, Dep: compound, Head: investments
# Token: investments, POS: NOUN, Dep: pobj, Head: for
# Token: in, POS: ADP, Dep: prep, Head: investments
# Token: AI, POS: PROPN, Dep: compound, Head: startups
# Token: startups, POS: NOUN, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: startups
# Token: which, POS: PRON, Dep: nsubj, Head: indicates
# Token: indicates, POS: VERB, Dep: relcl, Head: startups
# Token: its, POS: PRON, Dep: poss, Head: rate
# Token: growing, POS: VERB, Dep: amod, Head: rate
# Token: adoption, POS: NOUN, Dep: compound, Head: rate
# Token: rate, POS: NOUN, Dep: dobj, Head: indicates
# Token: by, POS: ADP, Dep: prep, Head: rate
# Token: businesses, POS: NOUN, Dep: pobj, Head: by
# Token: worldwide, POS: ADV, Dep: advmod, Head: rate
# Token: ., POS: PUNCT, Dep: punct, Head: accounts
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: In Asia and the Pacific, the market is expected to grow at a substantial CAGR over the next few years.
#
# Token: In, POS: ADP, Dep: prep, Head: expected
# Token: Asia, POS: PROPN, Dep: pobj, Head: In
# Token: and, POS: CCONJ, Dep: cc, Head: Asia
# Token: the, POS: DET, Dep: det, Head: Pacific
# Token: Pacific, POS: PROPN, Dep: conj, Head: Asia
# Token: ,, POS: PUNCT, Dep: punct, Head: expected
# Token: the, POS: DET, Dep: det, Head: market
# Token: market, POS: NOUN, Dep: nsubjpass, Head: expected
# Token: is, POS: AUX, Dep: auxpass, Head: expected
# Token: expected, POS: VERB, Dep: ROOT, Head: expected
# Token: to, POS: PART, Dep: aux, Head: grow
# Token: grow, POS: VERB, Dep: xcomp, Head: expected
# Token: at, POS: ADP, Dep: prep, Head: grow
# Token: a, POS: DET, Dep: det, Head: CAGR
# Token: substantial, POS: ADJ, Dep: amod, Head: CAGR
# Token: CAGR, POS: PROPN, Dep: pobj, Head: at
# Token: over, POS: ADP, Dep: prep, Head: grow
# Token: the, POS: DET, Dep: det, Head: years
# Token: next, POS: ADJ, Dep: amod, Head: years
# Token: few, POS: ADJ, Dep: amod, Head: years
# Token: years, POS: NOUN, Dep: pobj, Head: over
# Token: ., POS: PUNCT, Dep: punct, Head: expected
#
# Sentence: This expansion is attributable to the increased investments in artificial intelligence.
#
# Token: This, POS: DET, Dep: det, Head: expansion
# Token: expansion, POS: NOUN, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: attributable, POS: ADJ, Dep: acomp, Head: is
# Token: to, POS: ADP, Dep: prep, Head: attributable
# Token: the, POS: DET, Dep: det, Head: investments
# Token: increased, POS: VERB, Dep: amod, Head: investments
# Token: investments, POS: NOUN, Dep: pobj, Head: to
# Token: in, POS: ADP, Dep: prep, Head: investments
# Token: artificial, POS: ADJ, Dep: amod, Head: intelligence
# Token: intelligence, POS: NOUN, Dep: pobj, Head: in
# Token: ., POS: PUNCT, Dep: punct, Head: is
#
# Sentence: For example, Baidu, Inc., a Chinese Internet behemoth, stated in April 2018 that it had entered into definitive agreements with investors about the sale of its financial services group, which provides wealth management, consumer lending, and other commercial services.
#
# Token: For, POS: ADP, Dep: prep, Head: stated
# Token: example, POS: NOUN, Dep: pobj, Head: For
# Token: ,, POS: PUNCT, Dep: punct, Head: stated
# Token: Baidu, POS: PROPN, Dep: nmod, Head: Inc.
# Token: ,, POS: PUNCT, Dep: punct, Head: Inc.
# Token: Inc., POS: PROPN, Dep: nsubj, Head: stated
# Token: ,, POS: PUNCT, Dep: punct, Head: Inc.
# Token: a, POS: DET, Dep: det, Head: behemoth
# Token: Chinese, POS: ADJ, Dep: amod, Head: behemoth
# Token: Internet, POS: NOUN, Dep: compound, Head: behemoth
# Token: behemoth, POS: NOUN, Dep: appos, Head: Inc.
# Token: ,, POS: PUNCT, Dep: punct, Head: Inc.
# Token: stated, POS: VERB, Dep: ROOT, Head: stated
# Token: in, POS: ADP, Dep: prep, Head: stated
# Token: April, POS: PROPN, Dep: pobj, Head: in
# Token: 2018, POS: NUM, Dep: nummod, Head: April
# Token: that, POS: SCONJ, Dep: mark, Head: entered
# Token: it, POS: PRON, Dep: nsubj, Head: entered
# Token: had, POS: AUX, Dep: aux, Head: entered
# Token: entered, POS: VERB, Dep: ccomp, Head: stated
# Token: into, POS: ADP, Dep: prep, Head: entered
# Token: definitive, POS: ADJ, Dep: amod, Head: agreements
# Token: agreements, POS: NOUN, Dep: pobj, Head: into
# Token: with, POS: ADP, Dep: prep, Head: agreements
# Token: investors, POS: NOUN, Dep: pobj, Head: with
# Token: about, POS: ADP, Dep: prep, Head: entered
# Token: the, POS: DET, Dep: det, Head: sale
# Token: sale, POS: NOUN, Dep: pobj, Head: about
# Token: of, POS: ADP, Dep: prep, Head: sale
# Token: its, POS: PRON, Dep: poss, Head: group
# Token: financial, POS: ADJ, Dep: amod, Head: services
# Token: services, POS: NOUN, Dep: compound, Head: group
# Token: group, POS: NOUN, Dep: pobj, Head: of
# Token: ,, POS: PUNCT, Dep: punct, Head: group
# Token: which, POS: PRON, Dep: nsubj, Head: provides
# Token: provides, POS: VERB, Dep: relcl, Head: group
# Token: wealth, POS: NOUN, Dep: compound, Head: management
# Token: management, POS: NOUN, Dep: dobj, Head: provides
# Token: ,, POS: PUNCT, Dep: punct, Head: management
# Token: consumer, POS: NOUN, Dep: compound, Head: lending
# Token: lending, POS: NOUN, Dep: conj, Head: management
# Token: ,, POS: PUNCT, Dep: punct, Head: lending
# Token: and, POS: CCONJ, Dep: cc, Head: lending
# Token: other, POS: ADJ, Dep: amod, Head: services
# Token: commercial, POS: ADJ, Dep: amod, Head: services
# Token: services, POS: NOUN, Dep: conj, Head: lending
# Token: ., POS: PUNCT, Dep: punct, Head: stated
#
# Sentence: In addition, the increasing number of AI startups in the region is accelerating the implementation of AI to enhance operational efficiency and enable process automation.
#
#
#
# Token: In, POS: ADP, Dep: prep, Head: accelerating
# Token: addition, POS: NOUN, Dep: pobj, Head: In
# Token: ,, POS: PUNCT, Dep: punct, Head: accelerating
# Token: the, POS: DET, Dep: det, Head: number
# Token: increasing, POS: VERB, Dep: amod, Head: number
# Token: number, POS: NOUN, Dep: nsubj, Head: accelerating
# Token: of, POS: ADP, Dep: prep, Head: number
# Token: AI, POS: PROPN, Dep: compound, Head: startups
# Token: startups, POS: NOUN, Dep: pobj, Head: of
# Token: in, POS: ADP, Dep: prep, Head: startups
# Token: the, POS: DET, Dep: det, Head: region
# Token: region, POS: NOUN, Dep: pobj, Head: in
# Token: is, POS: AUX, Dep: aux, Head: accelerating
# Token: accelerating, POS: VERB, Dep: ROOT, Head: accelerating
# Token: the, POS: DET, Dep: det, Head: implementation
# Token: implementation, POS: NOUN, Dep: dobj, Head: accelerating
# Token: of, POS: ADP, Dep: prep, Head: implementation
# Token: AI, POS: PROPN, Dep: pobj, Head: of
# Token: to, POS: PART, Dep: aux, Head: enhance
# Token: enhance, POS: VERB, Dep: advcl, Head: accelerating
# Token: operational, POS: ADJ, Dep: amod, Head: efficiency
# Token: efficiency, POS: NOUN, Dep: dobj, Head: enhance
# Token: and, POS: CCONJ, Dep: cc, Head: enhance
# Token: enable, POS: ADJ, Dep: conj, Head: enhance
# Token: process, POS: NOUN, Dep: compound, Head: automation
# Token: automation, POS: NOUN, Dep: dobj, Head: enable
# Token: ., POS: PUNCT, Dep: punct, Head: accelerating
# Token:
#
# , POS: SPACE, Dep: dep, Head: .
#
# Sentence: ​​Additionally, the region is expected to continue growing in the healthcare, manufacturing, finance, and retail sectors.
#
# Token: ​​Additionally, POS: ADV, Dep: advmod, Head: expected
# Token: ,, POS: PUNCT, Dep: punct, Head: expected
# Token: the, POS: DET, Dep: det, Head: region
# Token: region, POS: NOUN, Dep: nsubjpass, Head: expected
# Token: is, POS: AUX, Dep: auxpass, Head: expected
# Token: expected, POS: VERB, Dep: ROOT, Head: expected
# Token: to, POS: PART, Dep: aux, Head: continue
# Token: continue, POS: VERB, Dep: xcomp, Head: expected
# Token: growing, POS: VERB, Dep: xcomp, Head: continue
# Token: in, POS: ADP, Dep: prep, Head: growing
# Token: the, POS: DET, Dep: det, Head: healthcare
# Token: healthcare, POS: NOUN, Dep: pobj, Head: in
# Token: ,, POS: PUNCT, Dep: punct, Head: healthcare
# Token: manufacturing, POS: NOUN, Dep: conj, Head: healthcare
# Token: ,, POS: PUNCT, Dep: punct, Head: manufacturing
# Token: finance, POS: NOUN, Dep: conj, Head: manufacturing
# Token: ,, POS: PUNCT, Dep: punct, Head: finance
# Token: and, POS: CCONJ, Dep: cc, Head: finance
# Token: retail, POS: ADJ, Dep: amod, Head: sectors
# Token: sectors, POS: NOUN, Dep: conj, Head: finance
# Token: ., POS: PUNCT, Dep: punct, Head: expected
#
# Sentence: This is due to increased revenue generated from the sale of AI products and
#
# Token: This, POS: PRON, Dep: nsubj, Head: is
# Token: is, POS: AUX, Dep: ROOT, Head: is
# Token: due, POS: ADJ, Dep: acomp, Head: is
# Token: to, POS: ADP, Dep: prep, Head: due
# Token: increased, POS: VERB, Dep: amod, Head: revenue
# Token: revenue, POS: NOUN, Dep: pobj, Head: to
# Token: generated, POS: VERB, Dep: acl, Head: revenue
# Token: from, POS: ADP, Dep: prep, Head: generated
# Token: the, POS: DET, Dep: det, Head: sale
# Token: sale, POS: NOUN, Dep: pobj, Head: from
# Token: of, POS: ADP, Dep: prep, Head: sale
# Token: AI, POS: PROPN, Dep: compound, Head: products
# Token: products, POS: NOUN, Dep: pobj, Head: of
# Token: and, POS: CCONJ, Dep: cc, Head: is
#
# Named Entities in ai_forecast2:
# Entity: $93.5 billion, Label: MONEY
# Entity: 2021, Label: DATE
# Entity: Grand View Research, Inc., Label: ORG
# Entity: annual, Label: DATE
# Entity: 38.1%, Label: PERCENT
# Entity: 2022, Label: DATE
# Entity: 2030, Label: DATE
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG
# Entity: around 66%, Label: PERCENT
# Entity: 2016, Label: DATE
# Entity: AI, Label: ORG
# Entity: eCommerce, Label: PRODUCT
# Entity: AI, Label: ORG
# Entity: NVIDIA Corporation, Label: ORG
# Entity: NVDA, Label: ORG
# Entity: Intel Corporation, Label: ORG
# Entity: Alphabet Inc., Label: ORG
# Entity: Amazon Web Services Inc., Label: ORG
# Entity: Artificial Intelligence Market by Component Analysis, Label: ORG
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG
# Entity: Artificial Intelligence Market by Technology
#
# , Label: ORG
# Entity: AI, Label: ORG
# Entity: NLP, Label: ORG
# Entity: AI, Label: GPE
# Entity: NLP, Label: ORG
# Entity: night, Label: TIME
# Entity: Artificial Intelligence Market by End-User Industry
#
# , Label: ORG
# Entity: AI, Label: ORG
# Entity: BFSI, Label: ORG
# Entity: AI, Label: ORG
# Entity: 2020, Label: DATE
# Entity: CoverGirl, Label: ORG
# Entity: the next few years, Label: DATE
# Entity: COVID-19, Label: ORG
# Entity: one, Label: CARDINAL
# Entity: COVID, Label: ORG
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG
# Entity: Erik Brynjolfsson, Label: PERSON
# Entity: Stanford Institute for Human-Centered AI, Label: ORG
# Entity: HAI, Label: ORG
# Entity: the Stanford Digital Economy Lab, Label: ORG
# Entity: AI, Label: ORG
# Entity: Stanford, Label: ORG
# Entity: AI, Label: ORG
# Entity: 2020, Label: DATE
# Entity: AI, Label: ORG
# Entity: COVID, Label: ORG
# Entity: AI, Label: ORG
# Entity: Brynjolfsson, Label: PERSON
# Entity: healthcare, Label: ORG
# Entity: AI, Label: GPE
# Entity: AI, Label: ORG
# Entity: COVID-19, Label: ORG
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG
# Entity: Growing Investments, Label: ORG
# Entity: Artificial Intelligence Systems, Label: ORG
# Entity: Tortoise Intelligence, Label: ORG
# Entity: AI, Label: ORG
# Entity: 115%, Label: PERCENT
# Entity: 2020, Label: DATE
# Entity: the biggest year-over-year, Label: DATE
# Entity: AI, Label: GPE
# Entity: at least two decades, Label: DATE
# Entity: AI, Label: GPE
# Entity: China, Label: GPE
# Entity: AI, Label: ORG
# Entity: The European Union, Label: ORG
# Entity: EU, Label: ORG
# Entity: Horizon 2020, Label: LAW
# Entity: €1 billion, Label: MONEY
# Entity: 2021, Label: DATE
# Entity: North America, Label: LOC
# Entity: AI, Label: ORG
# Entity: more than 42%, Label: PERCENT
# Entity: AI, Label: ORG
# Entity: Trump, Label: PERSON
# Entity: February 2019, Label: DATE
# Entity: AI, Label: ORG
# Entity: North America, Label: LOC
# Entity: AI, Label: ORG
# Entity: the coming years, Label: DATE
# Entity: North America, Label: LOC
# Entity: U.S., Label: GPE
# Entity: Canada, Label: GPE
# Entity: Mexico, Label: GPE
# Entity: AI, Label: ORG
# Entity: North America, Label: LOC
# Entity: AI, Label: ORG
# Entity: Asia, Label: LOC
# Entity: Pacific, Label: LOC
# Entity: the next few years, Label: DATE
# Entity: Baidu, Inc., Label: ORG
# Entity: Chinese, Label: NORP
# Entity: April 2018, Label: DATE
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG
# Entity: AI, Label: ORG

# %%
# Explain POS and dependency tag
print(spacy.explain("VERB")) 
print(spacy.explain("nsubj"))
# Out:
# verb
# nominal subject

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)

# Create a pattern for "Artificial Intelligence"
pattern = [{"LOWER": "artificial"}, {"LOWER": "intelligence"}]

matcher.add("AI_PHRASE", [pattern])
doc = nlp(ai_forecast2_text)
matches = matcher(doc)

for match_id, start, end in matches:
    matched_span = doc[start:end]
    print(f"Matched: '{matched_span.text}' at position {matched_span.start_char} to {matched_span.end_char}")
# Out:
# Matched: 'artificial intelligence' at position 11 to 34
# Matched: 'Artificial intelligence' at position 510 to 533
# Matched: 'artificial intelligence' at position 930 to 953
# Matched: 'Artificial Intelligence' at position 2111 to 2134
# Matched: 'Artificial Intelligence' at position 2662 to 2685
# Matched: 'artificial intelligence' at position 2744 to 2767
# Matched: 'Artificial Intelligence' at position 3761 to 3784
# Matched: 'artificial intelligence' at position 4606 to 4629
# Matched: 'Artificial Intelligence' at position 7144 to 7167
# Matched: 'artificial intelligence' at position 7866 to 7889
# Matched: 'artificial intelligence' at position 8341 to 8364
# Matched: 'artificial intelligence' at position 9199 to 9222

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)

# Create a pattern for "AI" followed by a verb
pattern = [{"LOWER": "ai"}, {"POS": "VERB"}]

matcher.add("AI_VERB", [pattern])
matches = matcher(doc)

for match_id, start, end in matches:
    matched_span = doc[start:end]
    print(f"Matched: '{matched_span.text}' at position {matched_span.start_char} to {matched_span.end_char}")
# Out:
# Matched: 'AI grew' at position 6191 to 6198

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)

# Create a pattern for numbers followed by "%"
pattern = [{"LIKE_NUM": True}, {"TEXT": "%"}]

matcher.add("PERCENTAGE", [pattern])
matches = matcher(doc)

for match_id, start, end in matches:
    matched_span = doc[start:end]
    print(f"Matched: '{matched_span.text}' at position {matched_span.start_char} to {matched_span.end_char}")
# Out:
# Matched: '38.1%' at position 187 to 192
# Matched: '66%' at position 1152 to 1155
# Matched: '115%' at position 7259 to 7263
# Matched: '42%' at position 8070 to 8073

# %%
# Extract organizations from the text
for ent in doc.ents:
    if ent.label_ == "ORG":
        print(f"Company Name: '{ent.text}' found at position {ent.start_char} to {ent.end_char}")
# Out:
# Company Name: 'Grand View Research, Inc.' found at position 91 to 116
# Company Name: 'AI' found at position 505 to 507
# Company Name: 'AI' found at position 817 to 819
# Company Name: 'AI' found at position 1193 to 1195
# Company Name: 'AI' found at position 1513 to 1515
# Company Name: 'NVIDIA Corporation' found at position 1763 to 1781
# Company Name: 'NVDA' found at position 1783 to 1787
# Company Name: 'Intel Corporation' found at position 1790 to 1807
# Company Name: 'Alphabet Inc.' found at position 1816 to 1829
# Company Name: 'Amazon Web Services Inc.' found at position 1843 to 1867
# Company Name: 'Artificial Intelligence Market by Component Analysis' found at position 2111 to 2163
# Company Name: 'AI' found at position 2352 to 2354
# Company Name: 'AI' found at position 2511 to 2513
# Company Name: 'Artificial Intelligence Market by Technology
#
# ' found at position 2662 to 2710
# Company Name: 'AI' found at position 2860 to 2862
# Company Name: 'NLP' found at position 2935 to 2938
# Company Name: 'NLP' found at position 3073 to 3076
# Company Name: 'Artificial Intelligence Market by End-User Industry
#
# ' found at position 3761 to 3816
# Company Name: 'AI' found at position 3820 to 3822
# Company Name: 'BFSI' found at position 3938 to 3942
# Company Name: 'AI' found at position 4125 to 4127
# Company Name: 'CoverGirl' found at position 4366 to 4375
# Company Name: 'COVID-19' found at position 5593 to 5601
# Company Name: 'COVID' found at position 5691 to 5696
# Company Name: 'AI' found at position 5708 to 5710
# Company Name: 'AI' found at position 5730 to 5732
# Company Name: 'Stanford Institute for Human-Centered AI' found at position 5850 to 5890
# Company Name: 'HAI' found at position 5892 to 5895
# Company Name: 'the Stanford Digital Economy Lab' found at position 5913 to 5945
# Company Name: 'AI' found at position 6097 to 6099
# Company Name: 'Stanford' found at position 6141 to 6149
# Company Name: 'AI' found at position 6191 to 6193
# Company Name: 'AI' found at position 6331 to 6333
# Company Name: 'COVID' found at position 6415 to 6420
# Company Name: 'AI' found at position 6476 to 6478
# Company Name: 'healthcare' found at position 6731 to 6741
# Company Name: 'AI' found at position 6873 to 6875
# Company Name: 'COVID-19' found at position 6922 to 6930
# Company Name: 'AI' found at position 6988 to 6990
# Company Name: 'AI' found at position 7117 to 7119
# Company Name: 'Growing Investments' found at position 7121 to 7140
# Company Name: 'Artificial Intelligence Systems' found at position 7144 to 7175
# Company Name: 'Tortoise Intelligence' found at position 7192 to 7213
# Company Name: 'AI' found at position 7236 to 7238
# Company Name: 'AI' found at position 7574 to 7576
# Company Name: 'The European Union' found at position 7688 to 7706
# Company Name: 'EU' found at position 7708 to 7710
# Company Name: 'AI' found at position 8013 to 8015
# Company Name: 'AI' found at position 8170 to 8172
# Company Name: 'AI' found at position 8443 to 8445
# Company Name: 'AI' found at position 8614 to 8616
# Company Name: 'AI' found at position 8831 to 8833
# Company Name: 'AI' found at position 8950 to 8952
# Company Name: 'Baidu, Inc.' found at position 9237 to 9248
# Company Name: 'AI' found at position 9531 to 9533
# Company Name: 'AI' found at position 9595 to 9597
# Company Name: 'AI' found at position 9846 to 9848

# %%
# Create a pattern to look for proper nouns (assuming they are typically multi-word proper nouns)
pattern = [{"POS": "PROPN"}, {"POS": "PROPN"}]

matcher.add("COMPANY_NAME", [pattern])
matches = matcher(doc)

for match_id, start, end in matches:
    matched_span = doc[start:end]
    print(f"Matched Company: '{matched_span.text}' at position {matched_span.start_char} to {matched_span.end_char}")
# Out:
# Matched Company: 'Grand View' at position 91 to 101
# Matched Company: 'View Research' at position 97 to 110
# Matched Company: '38.1%' at position 187 to 192
# Matched Company: '66%' at position 1152 to 1155
# Matched Company: 'NVIDIA Corporation' at position 1763 to 1781
# Matched Company: 'Intel Corporation' at position 1790 to 1807
# Matched Company: 'Alphabet Inc.' at position 1816 to 1829
# Matched Company: 'Amazon Web' at position 1843 to 1853
# Matched Company: 'Web Services' at position 1850 to 1862
# Matched Company: 'Services Inc.' at position 1854 to 1867
# Matched Company: 'Artificial Intelligence' at position 2111 to 2134
# Matched Company: 'Intelligence Market' at position 2122 to 2141
# Matched Company: 'Component Analysis' at position 2145 to 2163
# Matched Company: 'Artificial Intelligence' at position 2662 to 2685
# Matched Company: 'Intelligence Market' at position 2673 to 2692
# Matched Company: 'Artificial Intelligence' at position 3761 to 3784
# Matched Company: 'Intelligence Market' at position 3772 to 3791
# Matched Company: 'User Industry' at position 3799 to 3812
# Matched Company: 'COVID-19 Impact' at position 5451 to 5466
# Matched Company: 'Global Al' at position 5470 to 5479
# Matched Company: 'Al Market' at position 5477 to 5486
# Matched Company: 'Erik Brynjolfsson' at position 5800 to 5817
# Matched Company: 'Stanford Institute' at position 5850 to 5868
# Matched Company: 'Stanford Digital' at position 5917 to 5933
# Matched Company: 'Digital Economy' at position 5926 to 5941
# Matched Company: 'Economy Lab' at position 5934 to 5945
# Matched Company: 'Stanford HAI' at position 6141 to 6153
# Matched Company: 'Artificial Intelligence' at position 7144 to 7167
# Matched Company: 'Intelligence Systems' at position 7155 to 7175
# Matched Company: 'Tortoise Intelligence' at position 7192 to 7213
# Matched Company: '115%' at position 7259 to 7263
# Matched Company: 'European Union' at position 7692 to 7706
# Matched Company: 'North America' at position 7985 to 7998
# Matched Company: '42%' at position 8070 to 8073
# Matched Company: 'President Trump' at position 8219 to 8234
# Matched Company: 'American AI' at position 8248 to 8259
# Matched Company: 'AI Initiative' at position 8257 to 8270
# Matched Company: 'North America' at position 8555 to 8568
# Matched Company: 'North America' at position 8649 to 8662
# Matched Company: 'North America' at position 8880 to 8893
